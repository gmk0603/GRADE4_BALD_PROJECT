# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4316920646852235262
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1728525108
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16799211311506709643
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %%
import os
os.getcwd()
# Out:
# 'c:\\jupyter\\capston\\bald\\corneous'

# %% [markdown]
# # **1. 이미지 증식 및 npz 파일 생성**

# %%
import os, glob, random
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

## ImageDataGenerator를 활용하여 각 레이블당 이미지를 3배로 증식한 후, npz 파일 생성

datapath = "C:/jupyter/capston/bald/data/corneous" # 훈련 데이터 경로
output = "before_smote_corneous.npz"  # 저장할 파일 이름
x = []                    # Image
y = []                    # Label

datagen = ImageDataGenerator(
    rotation_range = 20,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    fill_mode = 'nearest',
    brightness_range = [0.7, 1.3]
)


# 폴더에 있는 이미지 데이터 읽기
# path를 통해 경로를 설정해주고, label을 통해 해당 이미지에 대한 라벨값을 지정해준다
# 예를 들어 양호 카테고리 이미지들은 0을 받아 지정해준다.
def glob_files(path, label, count):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    # 이미지 데이터 처리
    # 함수를 호출할 때마다 반복을 통해 데이터를 x,y 배열에 계속 집어넣는다.
    num = 0
    max_photo = count  # normal, mild, moderate, severe 중 가장 작은 이미지 개수로 설정
    for i, f in enumerate(files):
         # max_photo 값보다 커질 경우, 루프 벗어남.
        if num >= max_photo:   
            break
        num += 1
        
        # 이미지 데이터 읽기
        img = Image.open(f)
        img = img.resize((256,256))  # 이미지 사이즈 256 * 256 설정
        img = img.convert("RGB")
        img = np.asarray(img)        # RGB 색상값 0부터 1까지의 실수값 변환
        
        # 원본 이미지 저장
        x.append(img)
        y.append(label)
        
        # 이미지 증식
        # batch_size=1 -> 전체 이미지를 변형시킬 것이다.
        #img = img.reshape((1,) + img.shape)
        #for _ in range(2):
        #    for batch in datagen.flow(img, batch_size=1):
        #        augment_img = batch[0]
        #        x.append(augment_img)
        #        y.append(label)
        #        break

        if i % 100 == 0:
            print("run: " + f)

# 바꾼 코드 !!
# 폴더에 있는 이미지 데이터 읽고 레이블 지정
# 반복문을 통해 양호, 경증, 중등도, 중증 이미지를 가져온다.
# 또한 glob_files 함수를 호출할 때 각각의 라벨을 지정한다.
# i = 0 -> 양호, ... i = 3 -> 중증
# categories1: Training 데이터 이미지들 가져오기
# categories2: Validation 데이터 이미지들 가져오기
categories1 = ['normal', 'mild', 'moderate', 'severe']
categories2 = ['Valnormal', 'Valmild', 'Valmoderate', 'Valsevere']
def main():
    for i in range(4): 
        file = datapath + "/" + categories1[i]
        print(categories1[i] + " 실행")
        glob_files(file, i, 4000) # 534: Training 데이터의 normal 이미지 개수
    for i in range(4):
        file = datapath + "/" + categories2[i]
        print(categories2[i] + " 실행")
        glob_files(file, i, 1000) # 152: Validation 데이터의 normal 이미지 개수
        
    # 파일로 저장
    np.savez(output, x=x, y=y) # Numpy 압축파일로 저장
    print(str(len(x)) + "개의 이미지를 저장했습니다.")
    print("파일명: " + output)
    file_path = './before_smote_corneous.npz'
    file_size_gb = get_file_size(file_path)
    print(f"파일 용량: {file_size_gb:.2f} GB")  

# 파일 용량 GB 단위 출력
def get_file_size(file_path):
    size_in_bytes = os.path.getsize(file_path)
    size_in_gb = size_in_bytes / (1024 * 1024 * 1024)  # 바이트를 GB로 변환
    return size_in_gb
    
# 메인 프로그램 실행
# main() 함수를 실행하고 그 안에 있는 glob_files()함수를 통해 양호 경증 중증도 중증 순으로 함수를 다시 호출한다
# glob_files()함수를 통해 x, y배열에 데이터를 다 집어넣고
# np.savez를 통해 .npz형식의 데이터 배열 파일을 저장하게 된다.
if __name__ == '__main__':
    main()
# Out:
# normal 실행
# run: C:/jupyter/capston/bald/data/corneous/normal\6995_A2LEBJJDE00104R_1602829315024_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/normal\1015_A2LEBJJDE000592_1603083882814_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/normal\2983_A2LEBJJDE001261_1604285015229_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/normal\2983_A2LEBJJDE001261_1604221787062_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/normal\4002_A2LEBJJDE00137N_1606376670498_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/normal\1080_A2LEBJJDE00092R_1605843072294_2_TH.jpg
# mild 실행
# run: C:/jupyter/capston/bald/data/corneous/mild\1142_A2LEBJJDE00024K_1602477852151_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\7988_A2LEBJJDE00002B_1603607353904_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3977_A2LEBJJDE00027Y_1603780368714_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\6078_A2LEBJJDE00093K_1603535131598_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\6367_A2LEBJJDE00038L_1604197204603_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\9578_A2LEBJJDE00105K_1603681636607_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3332_A2LEBJJDE00100K_1603605288545_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\8814_A2LEBJJDE00118S_1604115652443_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\1798_A2LEBJJDE000539_1602494817519_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\4475_A2LEBJJDE00168X_1605056405840_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\0556_A2LEBJJDE00041T_1603420806957_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\6718_A2LEBJJDE000451_1602758385666_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\7216_A2LEBJJDE000125_1602465132445_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3977_A2LEBJJDE00029K_1602749581852_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\9578_A2LEBJJDE00105K_1603705790692_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\5237_A2LEBJJDE00029K_1603700774602_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3365_A2LEBJJDE00106D_1603176300201_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\9887_A2LEBJJDE00066H_1603779760474_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\0663_A2LEBJJDE001716_1604717812940_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\9887_A2LEBJJDE00066H_1602821903269_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\8100_A2LEBJJDE00010J_1602574372364_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\9887_A2LEBJJDE00066H_1603779641901_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\6609_A2LEBJJDE00127T_1603449147916_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\8224_A2LEBJJDE000448_1604114699482_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\1719_A2LEBJJDE00138G_1603621603732_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\6981_A2LEBJJDE00075I_1602914080391_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3937_A2LEBJJDE00046T_1603776188593_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3977_A2LEBJJDE00027Y_1605606458308_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\8337_A2LEBJJDE00109R_1603525393253_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\1069_A2LEBJJDE00094D_1605169667071_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3677_A2LEBJJDE00087X_1605578208397_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\6718_A2LEBJJDE000451_1603947116806_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\0844_A2LEBJJDE00067A_1603533803822_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\8262_A2LEBJJDE00047M_1602902411188_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\3654_A2LEBJJDE00016C_1602570015248_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\7584_A2LEBJJDE00189E_1604884428654_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\1145_A2LEBJJDE00119L_1604749388669_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\2404_A2LEBJJDE000175_1604307562341_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\1195_A2LEBJJDE00117Z_1602838475091_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/mild\5569_A2LEBJJDE001211_1605335371159_4_LH.jpg
# moderate 실행
# run: C:/jupyter/capston/bald/data/corneous/moderate\7366_A2LEBJJDE00143A_1602815500318_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2327_A2LEBJJDE00091Y_1604645744529_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2326_A2LEBJJDE00056N_1603519861820_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2820_A2LEBJJDE00179K_1605075113738_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\6981_A2LEBJJDE00075I_1604141645130_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\3046_A2LEBJJDE00089J_1605062208024_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\7338_A2LEBJJDE00006I_1603269522193_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2013_A2LEBJJDE00141O_1604298166898_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\9905_A2LEBJJDE00042M_1602898856509_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\5255_A2LEBJJDE00007B_1602898327032_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\9447_A2LEBJJDE001951_1604581074094_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\3937_A2LEBJJDE00046T_1603775793535_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\9874_A2LEBJJDE00123M_1605515420005_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2585_A2LEBJJDE001302_1604117306450_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\4162_A2LEBJJDE00013X_1603935488991_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\0013_A2LEBJJDE00060O_1603341963457_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2950_A2LEBJJDE00084J_1602926644539_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\0733_A2LEBJJDE000084_1602651616902_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\6818_A2LEBJJDE00170D_1605844793327_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2326_A2LEBJJDE00037S_1603938960312_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\4659_A2LEBJJDE001349_1603626031666_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\0770_A2LEBJJDE000865_1603072719254_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\6775_A2LEBJJDE00022Y_1605323152263_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\7939_A2LEBJJDE00023R_1602579550204_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\4162_A2LEBJJDE00013X_1603935043911_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\9447_A2LEBJJDE00145V_1603001268264_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\0770_A2LEBJJDE000865_1602998603661_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\7338_A2LEBJJDE00006I_1603954155988_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\6367_A2LEBJJDE00038L_1604197204603_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\9887_A2LEBJJDE00066H_1603426738596_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\3977_A2LEBJJDE00161C_1605590802520_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\6609_A2LEBJJDE00127T_1602850178437_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\4717_A2LEBJJDE001208_1605841296074_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\0844_A2LEBJJDE00067A_1604124018046_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\9527_A2LEBJJDE00110E_1604744524916_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\6718_A2LEBJJDE000451_1604636845405_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\7168_A2LEBJJDE00124F_1604194464099_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\8281_A2LEBJJDE00055U_1605937221466_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2404_A2LEBJJDE00020D_1604293969977_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/moderate\2959_A2LEBJJDE00097R_1602578922374_4_LH.jpg
# severe 실행
# run: C:/jupyter/capston/bald/data/corneous/severe\0733_A2LEBJJDE000084_1605863336095_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\5939_A2LEBJJDE00129F_1603529891925_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\1407_A2LEBJJDE001258_1605933573461_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\9874_A2LEBJJDE00123M_1604639102105_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\6718_A2LEBJJDE000451_1604636541507_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\3275_A2LEBJJDE001766_1605040141325_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\3275_A2LEBJJDE001766_1605942501103_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\9887_A2LEBJJDE00066H_1604904876167_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\8999_A2LEBJJDE00001I_1606036222990_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\5870_A2LEBJJDE00065O_1603445033861_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\7168_A2LEBJJDE00124F_1606450551593_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\0844_A2LEBJJDE00067A_1602914140837_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\9296_A2LEBJJDE00073W_1604106284615_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\6775_A2LEBJJDE00022Y_1606526344844_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\2404_A2LEBJJDE000175_1604555895281_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\1195_A2LEBJJDE00117Z_1603447215528_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\9296_A2LEBJJDE00073W_1604106284615_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\5415_A2LEBJJDE00032S_1603948919186_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\7338_A2LEBJJDE00006I_1603969668690_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\9874_A2LEBJJDE00123M_1604918673168_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\9400_A2LEBJJDE00078W_1606012008518_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\8337_A2LEBJJDE00109R_1603615340891_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/severe\2487_A2LEBJJDE00050U_1603348495158_6_BH.jpg
# Valnormal 실행
# run: C:/jupyter/capston/bald/data/corneous/Valnormal\8999_A2LEBJJDE00001I_1604718732223_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valnormal\7988_A2LEBJJDE000357_1604807839007_3_TH.jpg
# Valmild 실행
# run: C:/jupyter/capston/bald/data/corneous/Valmild\7418_A2LEBJJDE00080C_1606704680926_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\3365_A2LEBJJDE00106D_1606444989905_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\2326_A2LEBJJDE00037S_1606189701791_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\3085_A2LEBJJDE00128M_1606187712750_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\8102_A2LEBJJDE000633_1605944532391_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\4370_A1LCAIHDH00005Q_1607913254561_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\2800_A2LEBJJDE00036Z_1605864198706_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\3065_A2LEBJJDE00103Y_1606475123271_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\6570_A2LEBJJDE001675_1607830657797_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmild\8833_A2LEBJJDE00156I_1606275882468_2_TH.jpg
# Valmoderate 실행
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\1237_A2LEBJJDE001584_1606114225119_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\4970_A1LCAIHDH00010K_1607846268626_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\4370_A1LCAIHDH00005Q_1608431414270_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\2996_A2LEBJJDE00083Q_1606279973575_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\8212_A2LEBJJDE00070I_1606742805538_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\5849_A2LEBJJDE00015J_1606026819902_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\8896_A2LEBJJDE001807_1607653398984_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\2959_A2LEBJJDE00097R_1606021138008_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\5415_A2LEBJJDE00032S_1606041811281_2_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valmoderate\9578_A2LEBJJDE00105K_1606107689998_2_TH.jpg
# Valsevere 실행
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\9643_A2LEBJJDE00061H_1606712845806_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\5214_A2LEBJJDE001399_1607589470221_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\3006_A1LCAIHDH00007C_1608346711361_3_TH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\1981_A2LEBJJDE001493_1606635594657_6_BH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\3977_A2LCBJCAC000073_1607311890237_4_LH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\9244_A2LEBJJDE00154W_1607590309109_5_RH.jpg
# run: C:/jupyter/capston/bald/data/corneous/Valsevere\3332_A2LEBJJDE00100K_1606615204939_3_TH.jpg
# 13622개의 이미지를 저장했습니다.
# 파일명: before_smote_corneous.npz
# 파일 용량: 2.49 GB

# %% [markdown]
# ### **1-1. SMOTE 이전 label 개수 체크**

# %%
import numpy as np

## 각 label당 이미지 개수 추출

# npz 파일 불러오기
data = np.load('before_smote_corneous.npz')

# 레이블 데이터 로드
labels = data['y']

# 각 레이블의 개수 확인
# unique -> 중복된 라벨을 instinct시킴 즉 0~3
# counts -> return_counts 속성을 True로 설정해 각 라벨 수를 측정한다.
unique, counts = np.unique(labels,return_counts=True)
label_counts = dict(zip(unique, counts))

print("Label 개수: ", label_counts)
# Out:
# Label 개수:  {0: 686, 1: 5000, 2: 5000, 3: 2936}

# %% [markdown]
# ### npz 파일 확인

# %%
import numpy as np

# npz 파일 로드
data = np.load('before_smote_corneous.npz')

# npz 파일 내의 데이터 확인
print("불러온 데이터:")
for key in data.keys():
    print(key, ":", data[key])
# Out:
# 불러온 데이터:
# x : [[[[ 62  76  54]
#    [ 44  56  33]
#    [ 30  38  22]
#    ...
#    [ 70  77  66]
#    [109 121 105]
#    [ 93 101 112]]
#
#   [[ 46  73  61]
#    [ 35  59  38]
#    [ 30  42  23]
#    ...
#    [ 78  98  74]
#    [109 146 124]
#    [ 88 102 105]]
#
#   [[ 43  89  70]
#    [ 32  69  47]
#    [ 23  40  17]
#    ...
#    [ 86 107  83]
#    [ 78 129 116]
#    [ 82  98  95]]
#
#   ...
#
#   [[158 194 170]
#    [148 185 159]
#    [129 152 144]
#    ...
#    [200 225 227]
#    [201 221 224]
#    [202 225 221]]
#
#   [[170 203 190]
#    [174 205 192]
#    [175 196 189]
#    ...
#    [196 226 236]
#    [197 221 231]
#    [199 226 222]]
#
#   [[170 212 196]
#    [174 212 192]
#    [186 210 203]
#    ...
#    [194 231 236]
#    [194 223 229]
#    [196 230 217]]]
#
#
#  [[[197 221 225]
#    [216 236 240]
#    [200 229 229]
#    ...
#    [ 70  94  75]
#    [ 74 106  91]
#    [ 71 112  93]]
#
#   [[200 220 226]
#    [217 239 237]
#    [202 227 224]
#    ...
#    [ 65  95  62]
#    [ 77 106  90]
#    [ 78  96  78]]
#
#   [[194 213 222]
#    [216 235 232]
#    [203 223 219]
#    ...
#    [ 60  89  70]
#    [ 64  91  82]
#    [ 53  72  64]]
#
#   ...
#
#   [[155 192 196]
#    [155 179 181]
#    [164 193 190]
#    ...
#    [ 62  87  75]
#    [ 76  93  93]
#    [ 83 101  97]]
#
#   [[161 196 200]
#    [149 182 185]
#    [173 205 199]
#    ...
#    [ 72  97  83]
#    [ 85 104  98]
#    [112 125 101]]
#
#   [[130 164 167]
#    [158 199 201]
#    [181 214 215]
#    ...
#    [ 78 105  93]
#    [113 130 102]
#    [118 131  85]]]
#
#
#  [[[105 114 109]
#    [114 131 133]
#    [ 95 106  95]
#    ...
#    [104 106 110]
#    [132 147 136]
#    [124 139 130]]
#
#   [[ 82  90  77]
#    [117 135 126]
#    [106 118 109]
#    ...
#    [ 82  83  72]
#    [102 114 105]
#    [104 110 105]]
#
#   [[ 74  74  64]
#    [110 130 119]
#    [116 130 124]
#    ...
#    [ 71  79  68]
#    [ 68  81  66]
#    [ 75  84  76]]
#
#   ...
#
#   [[148 170 163]
#    [154 181 172]
#    [166 197 179]
#    ...
#    [162 191 211]
#    [164 195 204]
#    [157 195 201]]
#
#   [[152 172 171]
#    [164 189 186]
#    [183 207 204]
#    ...
#    [164 194 211]
#    [161 192 210]
#    [156 193 198]]
#
#   [[157 175 180]
#    [171 188 199]
#    [177 197 205]
#    ...
#    [162 197 207]
#    [156 194 214]
#    [154 192 203]]]
#
#
#  ...
#
#
#  [[[178 221 244]
#    [180 219 241]
#    [189 228 240]
#    ...
#    [125 143 155]
#    [127 144 166]
#    [125 148 177]]
#
#   [[185 222 244]
#    [186 226 248]
#    [200 233 246]
#    ...
#    [129 140 156]
#    [128 142 164]
#    [123 149 166]]
#
#   [[182 221 240]
#    [193 228 249]
#    [201 233 247]
#    ...
#    [130 145 153]
#    [130 143 163]
#    [125 151 160]]
#
#   ...
#
#   [[175 185 214]
#    [198 224 242]
#    [193 220 237]
#    ...
#    [152 138 144]
#    [154 141 145]
#    [152 144 141]]
#
#   [[166 175 195]
#    [189 216 239]
#    [199 231 248]
#    ...
#    [155 144 144]
#    [153 144 147]
#    [154 145 144]]
#
#   [[164 174 183]
#    [184 215 226]
#    [202 227 237]
#    ...
#    [151 148 159]
#    [148 149 148]
#    [148 146 137]]]
#
#
#  [[[145 145 104]
#    [144 139 105]
#    [149 135 107]
#    ...
#    [239 241 240]
#    [229 244 238]
#    [222 236 239]]
#
#   [[142 147 102]
#    [148 142 106]
#    [146 139 107]
#    ...
#    [235 241 240]
#    [232 242 236]
#    [222 240 229]]
#
#   [[141 140 105]
#    [152 136 108]
#    [145 142 106]
#    ...
#    [228 233 223]
#    [232 242 235]
#    [229 244 232]]
#
#   ...
#
#   [[160 193 184]
#    [173 196 191]
#    [173 194 197]
#    ...
#    [140 139 113]
#    [140 137 114]
#    [133 137 113]]
#
#   [[161 188 174]
#    [187 209 211]
#    [184 209 215]
#    ...
#    [137 139 109]
#    [134 138 107]
#    [129 137 102]]
#
#   [[160 177 174]
#    [179 206 202]
#    [184 212 215]
#    ...
#    [134 132 108]
#    [119 131  96]
#    [114 123  87]]]
#
#
#  [[[ 86  73  59]
#    [ 83  75  53]
#    [ 79  77  53]
#    ...
#    [ 65  79  53]
#    [ 64  77  59]
#    [ 65  75  60]]
#
#   [[ 89  74  51]
#    [ 78  75  47]
#    [ 79  77  52]
#    ...
#    [ 63  77  54]
#    [ 62  75  65]
#    [ 64  77  60]]
#
#   [[ 87  73  49]
#    [ 78  77  49]
#    [ 82  76  52]
#    ...
#    [ 58  70  53]
#    [ 60  69  60]
#    [ 58  71  53]]
#
#   ...
#
#   [[156 143 143]
#    [162 146 141]
#    [158 157 148]
#    ...
#    [129 103  83]
#    [127 100  85]
#    [117 101  78]]
#
#   [[158 142 139]
#    [155 147 135]
#    [159 153 138]
#    ...
#    [128 102  80]
#    [124 105  79]
#    [120 104  79]]
#
#   [[145 148 130]
#    [147 148 139]
#    [152 151 139]
#    ...
#    [117  99  78]
#    [118  98  76]
#    [116 100  81]]]]
# y : [0 0 0 ... 3 3 3]

# %% [markdown]
# ### SMOTE
# ###### 오류 해결(ModuleNotFoundError: No module named 'imblearn'
# https://stackoverflow.com/questions/47606873/jupyter-no-module-named-imblearn-after-installation

# %%
import numpy as np
from imblearn.over_sampling import SMOTE

# SMOTE 적용 후 output 파일명
output = "after_smote_corneous.npz"

# npz 파일 로드
data = np.load('before_smote_corneous.npz')
x = data['x']
y = data['y']

# 이미지 데이터를 벡터로 변환
x_vectorized = x.reshape(x.shape[0], -1)

# 라벨 0과 3의 인덱스 추출
label_0_indices = np.where(y == 0)[0]
label_3_indices = np.where(y == 3)[0]

# SMOTE를 사용하여 라벨 0과 3의 이미지를 증식
smote = SMOTE(sampling_strategy={0: 5000, 3: 5000})
x_resampled, y_resampled = smote.fit_resample(x_vectorized, y)

# 증식된 데이터를 다시 이미지 형태로 변환
x_resampled_reshaped = x_resampled.reshape(-1, x.shape[1], x.shape[2], x.shape[3])

# 증식된 데이터 저장
resampled_data = {'x': x_resampled_reshaped, 'y': y_resampled}
np.savez(output, **resampled_data)

print(str(len(x_resampled_reshaped)) + "개의 이미지를 오버샘플링했습니다.")
print("파일명: " + output)
file_path = './after_smote_corneous.npz'
file_size_gb = get_file_size(file_path)
print(f"파일 용량: {file_size_gb:.2f} GB")
# Out:
# 20000개의 이미지를 오버샘플링했습니다.
# 파일명: after_smote_corneous.npz
# 파일 용량: 3.66 GB

# %% [markdown]
# ### SMOTE 후 label 개수 체크

# %%
import numpy as np

## 각 label당 이미지 개수 추출

# npz 파일 불러오기
data = np.load('after_smote_corneous.npz')

# 레이블 데이터 로드
labels = data['y']

# 각 레이블의 개수 확인
# unique -> 중복된 라벨을 instinct시킴 즉 0~3
# counts -> return_counts 속성을 True로 설정해 각 라벨 수를 측정한다.
unique, counts = np.unique(labels,return_counts=True)
label_counts = dict(zip(unique, counts))

print("Label 개수: ", label_counts)
# Out:
# Label 개수:  {0: 5000, 1: 5000, 2: 5000, 3: 5000}

# %% [markdown]
# ### npz 파일 확인

# %%
import numpy as np

# npz 파일 로드
data = np.load('after_smote_corneous.npz')

# npz 파일 내의 데이터 확인
print("불러온 데이터:")
for key in data.keys():
    print(key, ":", data[key])
# Out:
# 불러온 데이터:
# x : [[[[ 62  76  54]
#    [ 44  56  33]
#    [ 30  38  22]
#    ...
#    [ 70  77  66]
#    [109 121 105]
#    [ 93 101 112]]
#
#   [[ 46  73  61]
#    [ 35  59  38]
#    [ 30  42  23]
#    ...
#    [ 78  98  74]
#    [109 146 124]
#    [ 88 102 105]]
#
#   [[ 43  89  70]
#    [ 32  69  47]
#    [ 23  40  17]
#    ...
#    [ 86 107  83]
#    [ 78 129 116]
#    [ 82  98  95]]
#
#   ...
#
#   [[158 194 170]
#    [148 185 159]
#    [129 152 144]
#    ...
#    [200 225 227]
#    [201 221 224]
#    [202 225 221]]
#
#   [[170 203 190]
#    [174 205 192]
#    [175 196 189]
#    ...
#    [196 226 236]
#    [197 221 231]
#    [199 226 222]]
#
#   [[170 212 196]
#    [174 212 192]
#    [186 210 203]
#    ...
#    [194 231 236]
#    [194 223 229]
#    [196 230 217]]]
#
#
#  [[[197 221 225]
#    [216 236 240]
#    [200 229 229]
#    ...
#    [ 70  94  75]
#    [ 74 106  91]
#    [ 71 112  93]]
#
#   [[200 220 226]
#    [217 239 237]
#    [202 227 224]
#    ...
#    [ 65  95  62]
#    [ 77 106  90]
#    [ 78  96  78]]
#
#   [[194 213 222]
#    [216 235 232]
#    [203 223 219]
#    ...
#    [ 60  89  70]
#    [ 64  91  82]
#    [ 53  72  64]]
#
#   ...
#
#   [[155 192 196]
#    [155 179 181]
#    [164 193 190]
#    ...
#    [ 62  87  75]
#    [ 76  93  93]
#    [ 83 101  97]]
#
#   [[161 196 200]
#    [149 182 185]
#    [173 205 199]
#    ...
#    [ 72  97  83]
#    [ 85 104  98]
#    [112 125 101]]
#
#   [[130 164 167]
#    [158 199 201]
#    [181 214 215]
#    ...
#    [ 78 105  93]
#    [113 130 102]
#    [118 131  85]]]
#
#
#  [[[105 114 109]
#    [114 131 133]
#    [ 95 106  95]
#    ...
#    [104 106 110]
#    [132 147 136]
#    [124 139 130]]
#
#   [[ 82  90  77]
#    [117 135 126]
#    [106 118 109]
#    ...
#    [ 82  83  72]
#    [102 114 105]
#    [104 110 105]]
#
#   [[ 74  74  64]
#    [110 130 119]
#    [116 130 124]
#    ...
#    [ 71  79  68]
#    [ 68  81  66]
#    [ 75  84  76]]
#
#   ...
#
#   [[148 170 163]
#    [154 181 172]
#    [166 197 179]
#    ...
#    [162 191 211]
#    [164 195 204]
#    [157 195 201]]
#
#   [[152 172 171]
#    [164 189 186]
#    [183 207 204]
#    ...
#    [164 194 211]
#    [161 192 210]
#    [156 193 198]]
#
#   [[157 175 180]
#    [171 188 199]
#    [177 197 205]
#    ...
#    [162 197 207]
#    [156 194 214]
#    [154 192 203]]]
#
#
#  ...
#
#
#  [[[141 146 136]
#    [142 151 144]
#    [129 148 134]
#    ...
#    [ 98  92  74]
#    [ 91  92  69]
#    [ 88  93  59]]
#
#   [[121 121 104]
#    [136 147 137]
#    [137 155 144]
#    ...
#    [ 95  86  67]
#    [ 93  88  63]
#    [ 90  87  55]]
#
#   [[110 104  79]
#    [109 114  97]
#    [121 130 125]
#    ...
#    [ 97  87  69]
#    [ 98  90  64]
#    [ 93  88  55]]
#
#   ...
#
#   [[157 173 152]
#    [154 164 151]
#    [154 163 150]
#    ...
#    [144 196 138]
#    [130 132 119]
#    [128 133 115]]
#
#   [[165 179 161]
#    [154 165 152]
#    [150 160 149]
#    ...
#    [139 140 130]
#    [130 134 114]
#    [121 127 107]]
#
#   [[182 248 186]
#    [160 177 162]
#    [145 158 147]
#    ...
#    [138 133 123]
#    [129 133 113]
#    [123 127 110]]]
#
#
#  [[[102 125 120]
#    [119 145 125]
#    [ 61  72  49]
#    ...
#    [229   6 243]
#    [226 252 245]
#    [210 237 239]]
#
#   [[112 132 111]
#    [119 145 114]
#    [ 70  85  53]
#    ...
#    [163 201 193]
#    [126 158 152]
#    [107 136 133]]
#
#   [[122 145 115]
#    [108 137 102]
#    [ 80  94  62]
#    ...
#    [ 64  96  80]
#    [ 58  86  68]
#    [ 57  79  66]]
#
#   ...
#
#   [[ 98 130 110]
#    [121 142 121]
#    [146 165 150]
#    ...
#    [ 72  78  51]
#    [ 74  77  53]
#    [ 73  80  55]]
#
#   [[ 93 120 103]
#    [113 134 113]
#    [112 128 113]
#    ...
#    [ 72  78  56]
#    [ 75  79  54]
#    [ 74  77  52]]
#
#   [[ 98 121 105]
#    [ 95 120  96]
#    [105 128 102]
#    ...
#    [ 71  80  59]
#    [ 73  82  54]
#    [ 76  83  47]]]
#
#
#  [[[143 157 144]
#    [132 146 134]
#    [124 135 123]
#    ...
#    [114 135 117]
#    [110 130 107]
#    [105 129  99]]
#
#   [[135 147 128]
#    [127 139 124]
#    [119 133 119]
#    ...
#    [115 137 117]
#    [104 136 106]
#    [106 129  97]]
#
#   [[132 136 121]
#    [125 132 121]
#    [117 132 121]
#    ...
#    [114 137 117]
#    [112 133 110]
#    [107 129  99]]
#
#   ...
#
#   [[129 143 134]
#    [128 141 128]
#    [127 140 130]
#    ...
#    [171 191 169]
#    [172 198 183]
#    [181 213 196]]
#
#   [[134 142 132]
#    [130 141 124]
#    [127 140 125]
#    ...
#    [170 190 168]
#    [169 196 181]
#    [173 201 185]]
#
#   [[131 144 128]
#    [128 142 123]
#    [126 141 119]
#    ...
#    [164 172 158]
#    [168 185 162]
#    [170 189 171]]]]
# y : [0 0 0 ... 3 3 3]

# %% [markdown]
# ### **1-2. npz 이미지 출력**
# imshow 오류 해결 링크: https://stackoverflow.com/questions/49643907/clipping-input-data-to-the-valid-range-for-imshow-with-rgb-data-0-1-for-floa

# %%
import matplotlib.pyplot as plt

# 이미지 확인
# np.load를 통해 배열 데이터를 가져오고 이를 photos변수에 집어넣는다
# photos 배열 데이터의 x= 이미지 y= 라벨을 각각 집어넣는다.
photos = np.load("after_smote_corneous.npz")
x = photos["x"]
y = photos["y"]

# 시작 인덱스 설정
idx = 0  

# subplot으로 인덱스로 설정한 이미지 출력
# plt.figure을 통해 최초 창의 크기를 가로 세로 9인치로 설정한다.
# 20번 반복해서 4행 5열 i+1번째에 이미지를 imshow를 통해 가져와서 출력한다.
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(x[i+idx].astype("uint8"))
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### smote 이미지(label 0) 출력

# %%
import numpy as np
import matplotlib.pyplot as plt

# npz 파일 로드
data = np.load('after_smote_corneous.npz')

# 이미지 데이터와 라벨 데이터 추출
x = data['x']
y = data['y']

# 라벨 0의 인덱스 추출
label_0_indices = np.where(y == 0)[0]

plt.figure(figsize=(10,10))

# 라벨 0의 이미지 샘플을 시각화
for i in range(20):
    plt.subplot(4, 5, i+1)
    index = label_0_indices[i]
    image = x[index]
    label = y[index]

    plt.imshow(image.astype("uint8"))
    plt.title(f'Label: {label}')
    
plt.tight_layout()    
plt.show()

# %% [markdown]
# # **2. 데이터셋 구분 및 실행**

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# npz 파일을 불러와 데이터셋 구분
def preprocessing(file, hairClass):
    global shape, x_train, y_train, x_val, y_val, x_test, y_test
    rows = 256                 # 이미지 높이
    cols = 256                 # 이미지 너비
    color = 3                  # 이미지 색공간
    shape = (rows, cols, color)
    hairClass = hairClass      # 출력 데이터 수
    
    # 사진 데이터 읽기
    # 데이터를 읽은 후 해당 파일의 x(이미지)는 x에  y(라벨 0,1,2,3)은 y에 넣는다.
    photo = np.load(file)
    x = photo['x']
    y = photo['y']
    
    # 데이터 1차원에서 3차원 배열로 변환 및 정규화
    x = x.reshape(-1, rows, cols, color)
    x = x.astype('float32') / 255
    
    # 레이블 One-Hot Encoding 변환
    y = to_categorical(y.astype('int32'), hairClass)
    
    # 전체 데이터셋 -> 학습 데이터셋과 테스트 데이터셋으로 구분
    x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                        test_size=0.1, random_state=77)
    
    # 훈련 데이터셋 -> 학습 데이터셋과 검증 데이터셋으로 구분
    # 만약 train_test_split의 test_size속성이 생략되어 있다면 해당 default값은 0.25이다.
    # 만약 train_test_split의 shuffle속성이 생략되어 있다면 해당 default값은 True이다.
    # 즉 데이터셋를 알아서 섞게 된다.
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
                                                      test_size=0.3, random_state=77)
    
    # 데이터셋 확인
    print(x_train.shape, y_train.shape)
    print(x_val.shape, y_val.shape)
    print(x_test.shape, y_test.shape)

# 데이터셋 구분 실행
# preprocessing을 통해 
preprocessing('after_smote_corneous.npz', 4)
# Out:
# (12600, 256, 256, 3) (12600, 4)
# (5400, 256, 256, 3) (5400, 4)
# (2000, 256, 256, 3) (2000, 4)

# %% [markdown]
# # **3. ImageNet: 모델 정의**

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet101, InceptionV3, Xception, EfficientNetB2

from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, BatchNormalization, Activation
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras import regularizers

# trainable 속성을 False로 설정하면 Imagenet 모델의 사전 학습된 가중치를 사용하여 모델의 예측을 생성한다.
# trainable 속성을 True로 설정하면 fine tuning을 수행할 수 있다.

# include_top 속성을 False로 설정하면 기존 Imagenet 모델의 Fully Connected Layer를 제외하고 가져온다.
# include_top 속성을 True로 설정하면 Fully Connected Layer를 포함한 Imagenet 모델을 전부 가져온다.

# InceptionV3 모델
def def_InceptionV3(shape, hairClass):
  pre_trained_inceptionv3 = InceptionV3(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_inceptionv3.trainable = False
  model = Sequential()
  model.add(pre_trained_inceptionv3)

  # 레이어 추가(재정의)
  model.add(GlobalAveragePooling2D())
  model.add(Dense(hairClass, activation='softmax'))
     
  # 모델 요약
  model.summary() 

  # 모델 컴파일
  model.compile(loss='categorical_crossentropy',
                     optimizer=Adam(learning_rate=1e-5),
                     metrics=['accuracy'])
  
  return model

# Xception 모델
def def_Xception(shape, hairClass):
  pre_trained_Xception = Xception(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_Xception.trainable = False
  model = Sequential()
  model.add(pre_trained_Xception)

  # 레이어 추가(재정의)
  model.add(GlobalAveragePooling2D())
  model.add(Dense(hairClass, activation='softmax'))

  # 모델 요약 
  model.summary() 

  # 모델 컴파일
  model.compile(loss='categorical_crossentropy',
                     optimizer=Adam(learning_rate=1e-5),
                     metrics=['accuracy'])
  
  return model

# %% [markdown]
# ### **3-1. 모델 학습, 저장 정의**

# %%
import tensorflow as tf
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

def model_train(x_train, y_train, x_val, y_val, modelFunc, modelName):
  # 모델 생성
  # shape는 데이터셋 구분시 초기화된 변수이다. -> (256, 256, 3)
  model = modelFunc(shape, 4)

  # 모델이 저장될 경로 체크
  model_dir = './model'

  if not os.path.exists(model_dir): # 해당 위치에 경로(폴더)가 없으면
    os.mkdir(model_dir) # 변수명 model_dir로 생성시킴

  # 폴더 경로 변경
  os.chdir('C:/jupyter/capston/bald/corneous/model')

  # 콜백 함수 설정
  # ModelCheckpoint란 모델을 저장할 때 사용하는 콜백 함수이다.
  # filepath -> 모델 저장 경로
  # monitor -> 모델 저장 시 기준이 되는 값으로 해당 코드에서는 val_loss을 저장하게 된다
  # verbose -> 1=저장되었다는 코맨트 0=코맨트 없음
  # save_besr_only -> monitor되는 값을 기준으로 가장 좋은 값을 저장한다.
  checkpoint = ModelCheckpoint(f'smote_Corneous_{modelName}.h5', monitor='val_loss', verbose=1, save_best_only=True)

  # EarlyStopping이란 특정 시점에서 훈련을 멈추는 콜백 함수이다.
  # monitor -> 모니터링할 값
  # mode -> 관찰항목에 대해 개선이 없다고 판단하기 위한 기준을 설정한다. 
  # monitor에서 설정한 항목이 val_loss 이면 값이 감소되지 않을 때 종료하여야 하므로 min을 설정한다. 입력하지 않으면 auto로 설정해 알아서 판단해준다.
  # patience -> 20번 이상 변동 없으면 중지시킨다. -> 일단 다 출력해본다.
  early_stopping = EarlyStopping(monitor='val_loss', patience=20)

  # 모델 훈련
  with tf.device("/device:GPU:0"):
    history = model.fit(x_train, y_train,
                        batch_size=30, 
                        epochs=100,
                        verbose=1,
                        validation_data=(x_val, y_val))
        
  
  # 모델 저장
  model.save(f'smote_Corneous_{modelName}.h5')

  return model, history

# %% [markdown]
# ### **모델 생성 및 훈련**

# %% [markdown]
# ### **InceptionV3 모델 생성 및 훈련**

# %%
model_Inception, history_Inception = model_train(x_train, y_train, x_val, y_val, def_InceptionV3, 'Inception')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 6, 6, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 8196
# =================================================================
# Total params: 21,810,980
# Trainable params: 8,196
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/30
# 420/420 [==============================] - 66s 137ms/step - loss: 1.3936 - accuracy: 0.3067 - val_loss: 1.3124 - val_accuracy: 0.3554
# Epoch 2/30
# 420/420 [==============================] - 57s 137ms/step - loss: 1.2693 - accuracy: 0.3804 - val_loss: 1.2192 - val_accuracy: 0.4144
# Epoch 3/30
# 420/420 [==============================] - 57s 136ms/step - loss: 1.1998 - accuracy: 0.4221 - val_loss: 1.1656 - val_accuracy: 0.4472
# Epoch 4/30
# 420/420 [==============================] - 58s 137ms/step - loss: 1.1565 - accuracy: 0.4461 - val_loss: 1.1277 - val_accuracy: 0.4689
# Epoch 5/30
# 420/420 [==============================] - 58s 138ms/step - loss: 1.1247 - accuracy: 0.4644 - val_loss: 1.0980 - val_accuracy: 0.4856
# Epoch 6/30
# 420/420 [==============================] - 61s 146ms/step - loss: 1.0996 - accuracy: 0.4787 - val_loss: 1.0753 - val_accuracy: 0.4954
# Epoch 7/30
# 420/420 [==============================] - 62s 149ms/step - loss: 1.0787 - accuracy: 0.4897 - val_loss: 1.0561 - val_accuracy: 0.5067
# Epoch 8/30
# 420/420 [==============================] - 62s 148ms/step - loss: 1.0612 - accuracy: 0.5031 - val_loss: 1.0401 - val_accuracy: 0.5115
# Epoch 9/30
# 420/420 [==============================] - 63s 150ms/step - loss: 1.0454 - accuracy: 0.5113 - val_loss: 1.0255 - val_accuracy: 0.5206
# Epoch 10/30
# 420/420 [==============================] - 60s 144ms/step - loss: 1.0316 - accuracy: 0.5195 - val_loss: 1.0130 - val_accuracy: 0.5270
# Epoch 11/30
# 420/420 [==============================] - 63s 149ms/step - loss: 1.0193 - accuracy: 0.5279 - val_loss: 1.0013 - val_accuracy: 0.5356
# Epoch 12/30
# 420/420 [==============================] - 65s 154ms/step - loss: 1.0082 - accuracy: 0.5351 - val_loss: 0.9921 - val_accuracy: 0.5400
# Epoch 13/30
# 420/420 [==============================] - 63s 150ms/step - loss: 0.9981 - accuracy: 0.5418 - val_loss: 0.9828 - val_accuracy: 0.5437
# Epoch 14/30
# 420/420 [==============================] - 60s 144ms/step - loss: 0.9893 - accuracy: 0.5463 - val_loss: 0.9742 - val_accuracy: 0.5522
# Epoch 15/30
# 420/420 [==============================] - 63s 149ms/step - loss: 0.9808 - accuracy: 0.5517 - val_loss: 0.9666 - val_accuracy: 0.5569
# Epoch 16/30
# 420/420 [==============================] - 63s 151ms/step - loss: 0.9730 - accuracy: 0.5563 - val_loss: 0.9609 - val_accuracy: 0.5544
# Epoch 17/30
# 420/420 [==============================] - 62s 147ms/step - loss: 0.9659 - accuracy: 0.5595 - val_loss: 0.9544 - val_accuracy: 0.5620
# Epoch 18/30
# 420/420 [==============================] - 62s 149ms/step - loss: 0.9594 - accuracy: 0.5641 - val_loss: 0.9483 - val_accuracy: 0.5646
# Epoch 19/30
# 420/420 [==============================] - 63s 149ms/step - loss: 0.9532 - accuracy: 0.5668 - val_loss: 0.9429 - val_accuracy: 0.5678
# Epoch 20/30
# 420/420 [==============================] - 63s 150ms/step - loss: 0.9475 - accuracy: 0.5707 - val_loss: 0.9371 - val_accuracy: 0.5709
# Epoch 21/30
# 420/420 [==============================] - 63s 151ms/step - loss: 0.9423 - accuracy: 0.5734 - val_loss: 0.9328 - val_accuracy: 0.5754
# Epoch 22/30
# 420/420 [==============================] - 63s 150ms/step - loss: 0.9371 - accuracy: 0.5771 - val_loss: 0.9287 - val_accuracy: 0.5780
# Epoch 23/30
# 420/420 [==============================] - 63s 150ms/step - loss: 0.9323 - accuracy: 0.5805 - val_loss: 0.9242 - val_accuracy: 0.5807
# Epoch 24/30
# 420/420 [==============================] - 63s 151ms/step - loss: 0.9279 - accuracy: 0.5835 - val_loss: 0.9203 - val_accuracy: 0.5809
# Epoch 25/30
# 420/420 [==============================] - 64s 152ms/step - loss: 0.9235 - accuracy: 0.5853 - val_loss: 0.9166 - val_accuracy: 0.5835
# Epoch 26/30
# 420/420 [==============================] - 64s 153ms/step - loss: 0.9194 - accuracy: 0.5887 - val_loss: 0.9136 - val_accuracy: 0.5885
# Epoch 27/30
# 420/420 [==============================] - 64s 152ms/step - loss: 0.9156 - accuracy: 0.5887 - val_loss: 0.9101 - val_accuracy: 0.5837
# Epoch 28/30
# 420/420 [==============================] - 65s 156ms/step - loss: 0.9119 - accuracy: 0.5920 - val_loss: 0.9075 - val_accuracy: 0.5876
# Epoch 29/30
# 420/420 [==============================] - 62s 148ms/step - loss: 0.9082 - accuracy: 0.5949 - val_loss: 0.9072 - val_accuracy: 0.5863
# Epoch 30/30
# 420/420 [==============================] - 63s 150ms/step - loss: 0.9049 - accuracy: 0.5963 - val_loss: 0.9021 - val_accuracy: 0.5885

# %%
model_Xception, history_Xception = model_train(x_train, y_train, x_val, y_val, def_Xception, 'Xception')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 8, 8, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 8196
# =================================================================
# Total params: 20,869,676
# Trainable params: 8,196
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/100
# 420/420 [==============================] - 110s 247ms/step - loss: 1.3288 - accuracy: 0.3663 - val_loss: 1.2813 - val_accuracy: 0.4093
# Epoch 2/100
# 420/420 [==============================] - 103s 246ms/step - loss: 1.2457 - accuracy: 0.4394 - val_loss: 1.2173 - val_accuracy: 0.4509
# Epoch 3/100
# 420/420 [==============================] - 105s 251ms/step - loss: 1.1927 - accuracy: 0.4668 - val_loss: 1.1738 - val_accuracy: 0.4757
# Epoch 4/100
# 420/420 [==============================] - 106s 253ms/step - loss: 1.1550 - accuracy: 0.4856 - val_loss: 1.1417 - val_accuracy: 0.4944
# Epoch 5/100
# 420/420 [==============================] - 112s 266ms/step - loss: 1.1261 - accuracy: 0.4985 - val_loss: 1.1161 - val_accuracy: 0.5013
# Epoch 6/100
# 420/420 [==============================] - 109s 260ms/step - loss: 1.1024 - accuracy: 0.5093 - val_loss: 1.0952 - val_accuracy: 0.5096
# Epoch 7/100
# 420/420 [==============================] - 107s 256ms/step - loss: 1.0823 - accuracy: 0.5212 - val_loss: 1.0768 - val_accuracy: 0.5178
# Epoch 8/100
# 420/420 [==============================] - 111s 266ms/step - loss: 1.0647 - accuracy: 0.5317 - val_loss: 1.0608 - val_accuracy: 0.5246
# Epoch 9/100
# 420/420 [==============================] - 111s 264ms/step - loss: 1.0492 - accuracy: 0.5387 - val_loss: 1.0461 - val_accuracy: 0.5335
# Epoch 10/100
# 420/420 [==============================] - 113s 270ms/step - loss: 1.0352 - accuracy: 0.5429 - val_loss: 1.0333 - val_accuracy: 0.5404
# Epoch 11/100
# 420/420 [==============================] - 113s 269ms/step - loss: 1.0228 - accuracy: 0.5514 - val_loss: 1.0219 - val_accuracy: 0.5463
# Epoch 12/100
# 420/420 [==============================] - 110s 262ms/step - loss: 1.0111 - accuracy: 0.5568 - val_loss: 1.0108 - val_accuracy: 0.5515
# Epoch 13/100
# 420/420 [==============================] - 109s 260ms/step - loss: 1.0006 - accuracy: 0.5623 - val_loss: 1.0015 - val_accuracy: 0.5522
# Epoch 14/100
# 420/420 [==============================] - 108s 258ms/step - loss: 0.9910 - accuracy: 0.5658 - val_loss: 0.9923 - val_accuracy: 0.5589
# Epoch 15/100
# 420/420 [==============================] - 108s 257ms/step - loss: 0.9820 - accuracy: 0.5702 - val_loss: 0.9840 - val_accuracy: 0.5654
# Epoch 16/100
# 420/420 [==============================] - 112s 267ms/step - loss: 0.9737 - accuracy: 0.5744 - val_loss: 0.9762 - val_accuracy: 0.5659
# Epoch 17/100
# 420/420 [==============================] - 112s 267ms/step - loss: 0.9659 - accuracy: 0.5815 - val_loss: 0.9692 - val_accuracy: 0.5715
# Epoch 18/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.9587 - accuracy: 0.5833 - val_loss: 0.9620 - val_accuracy: 0.5756
# Epoch 19/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.9519 - accuracy: 0.5859 - val_loss: 0.9565 - val_accuracy: 0.5739
# Epoch 20/100
# 420/420 [==============================] - 115s 274ms/step - loss: 0.9455 - accuracy: 0.5884 - val_loss: 0.9506 - val_accuracy: 0.5817
# Epoch 21/100
# 420/420 [==============================] - 108s 257ms/step - loss: 0.9397 - accuracy: 0.5924 - val_loss: 0.9447 - val_accuracy: 0.5830
# Epoch 22/100
# 420/420 [==============================] - 108s 258ms/step - loss: 0.9340 - accuracy: 0.5952 - val_loss: 0.9396 - val_accuracy: 0.5848
# Epoch 23/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.9288 - accuracy: 0.5987 - val_loss: 0.9344 - val_accuracy: 0.5885
# Epoch 24/100
# 420/420 [==============================] - 110s 263ms/step - loss: 0.9238 - accuracy: 0.6008 - val_loss: 0.9300 - val_accuracy: 0.5894
# Epoch 25/100
# 420/420 [==============================] - 113s 268ms/step - loss: 0.9191 - accuracy: 0.6028 - val_loss: 0.9259 - val_accuracy: 0.5911
# Epoch 26/100
# 420/420 [==============================] - 112s 266ms/step - loss: 0.9145 - accuracy: 0.6056 - val_loss: 0.9217 - val_accuracy: 0.5928
# Epoch 27/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.9103 - accuracy: 0.6080 - val_loss: 0.9180 - val_accuracy: 0.5926
# Epoch 28/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.9063 - accuracy: 0.6097 - val_loss: 0.9146 - val_accuracy: 0.5935
# Epoch 29/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.9025 - accuracy: 0.6124 - val_loss: 0.9103 - val_accuracy: 0.5954
# Epoch 30/100
# 420/420 [==============================] - 112s 266ms/step - loss: 0.8987 - accuracy: 0.6127 - val_loss: 0.9071 - val_accuracy: 0.5981
# Epoch 31/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8953 - accuracy: 0.6139 - val_loss: 0.9037 - val_accuracy: 0.6000
# Epoch 32/100
# 420/420 [==============================] - 114s 272ms/step - loss: 0.8919 - accuracy: 0.6141 - val_loss: 0.9006 - val_accuracy: 0.6007
# Epoch 33/100
# 420/420 [==============================] - 116s 276ms/step - loss: 0.8885 - accuracy: 0.6164 - val_loss: 0.8981 - val_accuracy: 0.6006
# Epoch 34/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8854 - accuracy: 0.6160 - val_loss: 0.8947 - val_accuracy: 0.6041
# Epoch 35/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.8825 - accuracy: 0.6159 - val_loss: 0.8924 - val_accuracy: 0.6043
# Epoch 36/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.8796 - accuracy: 0.6186 - val_loss: 0.8895 - val_accuracy: 0.6074
# Epoch 37/100
# 420/420 [==============================] - 109s 260ms/step - loss: 0.8769 - accuracy: 0.6192 - val_loss: 0.8872 - val_accuracy: 0.6085
# Epoch 38/100
# 420/420 [==============================] - 110s 261ms/step - loss: 0.8742 - accuracy: 0.6182 - val_loss: 0.8847 - val_accuracy: 0.6102
# Epoch 39/100
# 420/420 [==============================] - 112s 266ms/step - loss: 0.8717 - accuracy: 0.6223 - val_loss: 0.8825 - val_accuracy: 0.6109
# Epoch 40/100
# 420/420 [==============================] - 109s 259ms/step - loss: 0.8693 - accuracy: 0.6215 - val_loss: 0.8806 - val_accuracy: 0.6098
# Epoch 41/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.8669 - accuracy: 0.6239 - val_loss: 0.8783 - val_accuracy: 0.6122
# Epoch 42/100
# 420/420 [==============================] - 110s 263ms/step - loss: 0.8646 - accuracy: 0.6242 - val_loss: 0.8763 - val_accuracy: 0.6130
# Epoch 43/100
# 420/420 [==============================] - 110s 262ms/step - loss: 0.8623 - accuracy: 0.6235 - val_loss: 0.8741 - val_accuracy: 0.6144
# Epoch 44/100
# 420/420 [==============================] - 111s 265ms/step - loss: 0.8602 - accuracy: 0.6262 - val_loss: 0.8724 - val_accuracy: 0.6139
# Epoch 45/100
# 420/420 [==============================] - 114s 271ms/step - loss: 0.8580 - accuracy: 0.6273 - val_loss: 0.8704 - val_accuracy: 0.6165
# Epoch 46/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8560 - accuracy: 0.6275 - val_loss: 0.8688 - val_accuracy: 0.6154
# Epoch 47/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8540 - accuracy: 0.6272 - val_loss: 0.8672 - val_accuracy: 0.6169
# Epoch 48/100
# 420/420 [==============================] - 114s 271ms/step - loss: 0.8521 - accuracy: 0.6289 - val_loss: 0.8654 - val_accuracy: 0.6189
# Epoch 49/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8503 - accuracy: 0.6297 - val_loss: 0.8637 - val_accuracy: 0.6196
# Epoch 50/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8484 - accuracy: 0.6311 - val_loss: 0.8625 - val_accuracy: 0.6209
# Epoch 51/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8466 - accuracy: 0.6295 - val_loss: 0.8602 - val_accuracy: 0.6215
# Epoch 52/100
# 420/420 [==============================] - 114s 273ms/step - loss: 0.8449 - accuracy: 0.6321 - val_loss: 0.8591 - val_accuracy: 0.6228
# Epoch 53/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8432 - accuracy: 0.6325 - val_loss: 0.8576 - val_accuracy: 0.6226
# Epoch 54/100
# 420/420 [==============================] - 112s 266ms/step - loss: 0.8415 - accuracy: 0.6330 - val_loss: 0.8561 - val_accuracy: 0.6226
# Epoch 55/100
# 420/420 [==============================] - 115s 275ms/step - loss: 0.8399 - accuracy: 0.6340 - val_loss: 0.8551 - val_accuracy: 0.6254
# Epoch 56/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.8384 - accuracy: 0.6344 - val_loss: 0.8536 - val_accuracy: 0.6257
# Epoch 57/100
# 420/420 [==============================] - 113s 268ms/step - loss: 0.8368 - accuracy: 0.6330 - val_loss: 0.8520 - val_accuracy: 0.6256
# Epoch 58/100
# 420/420 [==============================] - 112s 267ms/step - loss: 0.8354 - accuracy: 0.6336 - val_loss: 0.8509 - val_accuracy: 0.6244
# Epoch 59/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8339 - accuracy: 0.6351 - val_loss: 0.8494 - val_accuracy: 0.6252
# Epoch 60/100
# 420/420 [==============================] - 113s 268ms/step - loss: 0.8324 - accuracy: 0.6348 - val_loss: 0.8480 - val_accuracy: 0.6270
# Epoch 61/100
# 420/420 [==============================] - 112s 266ms/step - loss: 0.8310 - accuracy: 0.6366 - val_loss: 0.8474 - val_accuracy: 0.6263
# Epoch 62/100
# 420/420 [==============================] - 112s 267ms/step - loss: 0.8297 - accuracy: 0.6351 - val_loss: 0.8458 - val_accuracy: 0.6256
# Epoch 63/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8283 - accuracy: 0.6359 - val_loss: 0.8449 - val_accuracy: 0.6263
# Epoch 64/100
# 420/420 [==============================] - 111s 266ms/step - loss: 0.8269 - accuracy: 0.6366 - val_loss: 0.8439 - val_accuracy: 0.6256
# Epoch 65/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8257 - accuracy: 0.6367 - val_loss: 0.8427 - val_accuracy: 0.6280
# Epoch 66/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.8243 - accuracy: 0.6390 - val_loss: 0.8411 - val_accuracy: 0.6278
# Epoch 67/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8232 - accuracy: 0.6379 - val_loss: 0.8405 - val_accuracy: 0.6294
# Epoch 68/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.8219 - accuracy: 0.6371 - val_loss: 0.8400 - val_accuracy: 0.6287
# Epoch 69/100
# 420/420 [==============================] - 114s 272ms/step - loss: 0.8208 - accuracy: 0.6382 - val_loss: 0.8389 - val_accuracy: 0.6306
# Epoch 70/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8196 - accuracy: 0.6401 - val_loss: 0.8374 - val_accuracy: 0.6307
# Epoch 71/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8184 - accuracy: 0.6394 - val_loss: 0.8366 - val_accuracy: 0.6300
# Epoch 72/100
# 420/420 [==============================] - 114s 271ms/step - loss: 0.8172 - accuracy: 0.6396 - val_loss: 0.8354 - val_accuracy: 0.6291
# Epoch 73/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.8161 - accuracy: 0.6405 - val_loss: 0.8345 - val_accuracy: 0.6326
# Epoch 74/100
# 420/420 [==============================] - 114s 273ms/step - loss: 0.8150 - accuracy: 0.6417 - val_loss: 0.8336 - val_accuracy: 0.6302
# Epoch 75/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.8140 - accuracy: 0.6423 - val_loss: 0.8330 - val_accuracy: 0.6319
# Epoch 76/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8128 - accuracy: 0.6416 - val_loss: 0.8318 - val_accuracy: 0.6320
# Epoch 77/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8118 - accuracy: 0.6413 - val_loss: 0.8314 - val_accuracy: 0.6322
# Epoch 78/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.8108 - accuracy: 0.6430 - val_loss: 0.8305 - val_accuracy: 0.6324
# Epoch 79/100
# 420/420 [==============================] - 111s 265ms/step - loss: 0.8097 - accuracy: 0.6430 - val_loss: 0.8294 - val_accuracy: 0.6335
# Epoch 80/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8086 - accuracy: 0.6429 - val_loss: 0.8285 - val_accuracy: 0.6317
# Epoch 81/100
# 420/420 [==============================] - 114s 272ms/step - loss: 0.8077 - accuracy: 0.6437 - val_loss: 0.8277 - val_accuracy: 0.6320
# Epoch 82/100
# 420/420 [==============================] - 114s 273ms/step - loss: 0.8067 - accuracy: 0.6429 - val_loss: 0.8269 - val_accuracy: 0.6344
# Epoch 83/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8058 - accuracy: 0.6432 - val_loss: 0.8262 - val_accuracy: 0.6335
# Epoch 84/100
# 420/420 [==============================] - 114s 271ms/step - loss: 0.8048 - accuracy: 0.6445 - val_loss: 0.8253 - val_accuracy: 0.6320
# Epoch 85/100
# 420/420 [==============================] - 112s 268ms/step - loss: 0.8038 - accuracy: 0.6453 - val_loss: 0.8248 - val_accuracy: 0.6328
# Epoch 86/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8029 - accuracy: 0.6460 - val_loss: 0.8237 - val_accuracy: 0.6320
# Epoch 87/100
# 420/420 [==============================] - 114s 272ms/step - loss: 0.8020 - accuracy: 0.6470 - val_loss: 0.8232 - val_accuracy: 0.6331
# Epoch 88/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.8012 - accuracy: 0.6468 - val_loss: 0.8228 - val_accuracy: 0.6337
# Epoch 89/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.8003 - accuracy: 0.6479 - val_loss: 0.8220 - val_accuracy: 0.6331
# Epoch 90/100
# 420/420 [==============================] - 111s 264ms/step - loss: 0.7994 - accuracy: 0.6481 - val_loss: 0.8210 - val_accuracy: 0.6341
# Epoch 91/100
# 420/420 [==============================] - 110s 263ms/step - loss: 0.7985 - accuracy: 0.6487 - val_loss: 0.8205 - val_accuracy: 0.6343
# Epoch 92/100
# 420/420 [==============================] - 110s 262ms/step - loss: 0.7976 - accuracy: 0.6480 - val_loss: 0.8202 - val_accuracy: 0.6352
# Epoch 93/100
# 420/420 [==============================] - 113s 269ms/step - loss: 0.7968 - accuracy: 0.6499 - val_loss: 0.8193 - val_accuracy: 0.6331
# Epoch 94/100
# 420/420 [==============================] - 113s 270ms/step - loss: 0.7961 - accuracy: 0.6485 - val_loss: 0.8184 - val_accuracy: 0.6352
# Epoch 95/100
# 420/420 [==============================] - 112s 267ms/step - loss: 0.7952 - accuracy: 0.6506 - val_loss: 0.8179 - val_accuracy: 0.6350
# Epoch 96/100
# 420/420 [==============================] - 109s 260ms/step - loss: 0.7944 - accuracy: 0.6508 - val_loss: 0.8177 - val_accuracy: 0.6367
# Epoch 97/100
# 420/420 [==============================] - 114s 271ms/step - loss: 0.7935 - accuracy: 0.6504 - val_loss: 0.8165 - val_accuracy: 0.6357
# Epoch 98/100
# 420/420 [==============================] - 109s 259ms/step - loss: 0.7928 - accuracy: 0.6513 - val_loss: 0.8162 - val_accuracy: 0.6367
# Epoch 99/100
# 420/420 [==============================] - 110s 263ms/step - loss: 0.7920 - accuracy: 0.6511 - val_loss: 0.8154 - val_accuracy: 0.6365
# Epoch 100/100
# 420/420 [==============================] - 114s 271ms/step - loss: 0.7912 - accuracy: 0.6511 - val_loss: 0.8147 - val_accuracy: 0.6370
# C:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ### **3-2. history 확인**

# %%
# 나머지 모델 또한 동일함

print(history_Inception.history.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5668\2565784375.py in <module>
#       1 # 나머지 모델 또한 동일함
#       2
# ----> 3 print(history_Inception.history.keys())
#
# NameError: name 'history_Inception' is not defined

# %% [markdown]
# ### **4. 그래프 정의**

# %%
import matplotlib.pyplot as plt

def model_plot(history, modelName):
  # loss
  y_loss = history.history['loss']
  y_vloss = history.history['val_loss']
  
  x_len = range(1,len(y_loss) + 1)

  fig = plt.figure(figsize=(10, 4))
  ax = fig.add_subplot(1, 2, 1)

  ax.plot(x_len, y_loss, marker='.', c='blue', label='train_set_loss')
  ax.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
  ax.set_xlabel('Epochs')
  ax.set_ylabel('Loss')
  ax.set_title(modelName + ': train&val loss')
  ax.legend()

  # accuracy
  y_acc = history.history['accuracy']
  y_vacc = history.history['val_accuracy']
  
  x_len = range(1, len(y_acc) + 1)
  ax = fig.add_subplot(1, 2, 2)
  ax.plot(x_len, y_acc, marker='.', c='blue', label='train_set_acc')
  ax.plot(x_len, y_vacc, marker='.', c='red', label='val_set_acc')
  ax.set_xlabel('Epochs')
  ax.set_ylabel('Accuracy')
  ax.set_title(modelName + ': train&val accuracy')
  ax.legend()

  plt.tight_layout()
  plt.show()

# %% [markdown]
# ### **4-1. 그래프 출력**

# %%
model_plot(history_Xception, 'Xception')

# %% [markdown]
# ### **5. 혼돈행렬 정의**

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# history와 model을 이용한 방법
def confusionMatrix_model(model, modelName, x_test, y_test):
    # 모델을 이용해 테스트 데이터셋에 대한 예측 수행
    y_pred = model.predict(x_test)

    # softmax 확률 출력을 가장 높은 확률을 가진 클래스로 변환
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Labeling
    label = ['normal', 'mild', 'moderate', 'severe']
    
    # 혼동 행렬 생성
    cm = confusion_matrix(y_true, y_pred_classes)

    # 혼동 행렬 시각화
    plt.figure(figsize=(7,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label, yticklabels=label)
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.title(modelName + ' confusionMatrix')
    plt.show()

    # 분류 보고서 출력
    print(classification_report(y_true, y_pred_classes))

    
# 생성된 .h5 파일을 이용하여 생성
def confusionMatrix_h5(model_path, modelName, x_test, y_test):
    
    # 모델 로드
    model = load_model(model_path)

    # 테스트 데이터셋에 대한 예측 수행
    y_pred = model.predict(x_test)

    # 예측 결과를 가장 높은 확률을 가진 클래스로 변환
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # 혼동 행렬 생성
    cm = confusion_matrix(y_true, y_pred_classes)

    # 혼동 행렬 시각화
    plt.figure(figsize=(7,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.title(modelName + ' confusionMatrix')
    plt.show()

# %% [markdown]
# ### **5-1. 혼돈행렬 출력**

# %%
with tf.device("/device:CPU:0"):
    confusionMatrix_model(model_Xception, 'Xception', x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       509
#            1       0.58      0.64      0.61       511
#            2       0.48      0.52      0.50       480
#            3       0.74      0.66      0.70       500
#
#     accuracy                           0.65      2000
#    macro avg       0.66      0.65      0.65      2000
# weighted avg       0.66      0.65      0.66      2000

# %% [markdown]
# # **6. 모델 evaluate 정의**

# %%
def model_evaluate(model, x_test, y_test):
    test_result = model.evaluate(x_test, y_test, verbose=1)
    print("acc: ", test_result[1], 'loss: ', test_result[0])

    return test_result[1], test_result[0]

# %% [markdown]
# # **6-1. 모델 evaluate 출력**

# %%
with tf.device("/device:CPU:0"):
    accuracy_Xception, loss_Xception = model_evaluate(model_Xception, x_test, y_test)
# Out:
# 63/63 [==============================] - 94s 1s/step - loss: 0.8088 - accuracy: 0.6510
# acc:  0.6510000228881836 loss:  0.8088170886039734
