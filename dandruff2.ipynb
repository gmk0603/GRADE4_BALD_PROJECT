# %% [markdown]
# # 미세각질 Imagenet 모델 중 EfficientNetB2를 제외한 나머지 결과

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# npz파일 생성

# %%
import os, glob, random
import numpy as np
from PIL import Image

datapath = "/content/drive/MyDrive/data/dandruff" # 훈련 데이터 경로
output = "dandruffLoss.npz"  # 저장할 파일 이름

image_w = 256
image_h = 256

x = []                    # Image
y = []                    # Label

# 폴더에 있는 이미지 데이터 읽기
# path를 통해 경로를 설정해주고, label을 통해 해당 이미지에 대한 라벨값을 지정해준다
# 예를 들어 양호 카테고리 이미지들은 0을 받아 지정해준다.
def glob_files(path, label):
    files = glob.glob(path + "/*.jpg")
    random.shuffle(files)
    
    # 이미지 데이터 처리
    # 함수를 호출할 때마다 반복을 통해 데이터를 x,y 배열에 계속 집어넣는다.
    num = 0
    max_photo = 534            # normal, mild, moderate, severe 중 가장 작은 이미지 개수로 설정
    for i, f in enumerate(files):
        if num >= max_photo:   # max_photo 값보다 커질 경우, 루프 벗어남.
            break
        num += 1
        
        # 이미지 데이터 읽기
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))  # 이미지 사이즈 256 * 256 설정
        img = np.asarray(img)        # RGB 색상값 0부터 1까지의 실수값 변환
        x.append(img)
        y.append(label)
        
        if i % 100 == 0:
            print("run: " + f)

# 바꾼 코드 !!
# 폴더에 있는 이미지 데이터 읽고 레이블 지정
# 반복문을 통해 양호, 경증, 중등도, 중증 이미지를 가져온다.
# 또한 glob_files 함수를 호출할 때 각각의 라벨을 지정한다.
# i = 0 -> 양호, ... i = 3 -> 중증
categories = ['normal', 'mild', 'moderate', 'severe']
def main():
    for i in range(4): 
        file = datapath + "/" + categories[i]
        print(categories[i] + " 실행")
        glob_files(file, i)
        
    # 파일로 저장
    np.savez(output, x=x, y=y) # Numpy 압축파일로 저장
    print(str(len(x)) + "개의 이미지를 저장했습니다. 파일명: " + output)
    
# 메인 프로그램 실행
# main() 함수를 실행하고 그 안에 있는 glob_files()함수를 통해 양호 경증 중증도 중증 순으로 함수를 다시 호출한다
# glob_files()함수를 통해 x, y배열에 데이터를 다 집어넣고
# np.savez를 통해 .npz형식의 데이터 배열 파일을 저장하게 된다.
if __name__ == '__main__':
    main()
# Out:
# normal 실행
# run: /content/drive/MyDrive/data/dandruff/normal/1940_A2LEBJJDE000307_1602650668680_4_LH.jpg
# run: /content/drive/MyDrive/data/dandruff/normal/5939_A2LEBJJDE00129F_1605669339027_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/normal/6775_A2LEBJJDE00022Y_1605248510032_3_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/normal/1069_A2LEBJJDE00094D_1606717017580_4_LH.jpg
# run: /content/drive/MyDrive/data/dandruff/normal/1940_A2LEBJJDE000307_1602650631395_2_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/normal/6437_A1LCAIHDH00019R_1609995437154_5_RH.jpg
# mild 실행
# run: /content/drive/MyDrive/data/dandruff/mild/3832_A2LEBJJDE00140V_1602765493221_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/mild/6995_A2LEBJJDE00104R_1604715657743_2_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/mild/9887_A2LEBJJDE00066H_1604904942220_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/mild/4557_A2LEBJJDE00043F_1603177174184_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/mild/9316_A2LEBJJDE00034E_1605756044860_4_LH.jpg
# run: /content/drive/MyDrive/data/dandruff/mild/5030_A2LEBJJDE00186Z_1604450078940_3_TH.jpg
# moderate 실행
# run: /content/drive/MyDrive/data/dandruff/moderate/5619_A2LEBJJDE00002B_1606354206843_5_RH.jpg
# run: /content/drive/MyDrive/data/dandruff/moderate/9578_A2LEBJJDE00105K_1603943811457_3_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/moderate/3332_A2LEBJJDE00100K_1605416672192_4_LH.jpg
# run: /content/drive/MyDrive/data/dandruff/moderate/5750_A2LEBJJDE000589_1604808860445_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/moderate/3858_A2LEBJJDE00076B_1602644454735_3_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/moderate/5854_A2LEBJJDE00157B_1604458718275_6_BH.jpg
# severe 실행
# run: /content/drive/MyDrive/data/dandruff/severe/4162_A2LEBJJDE00013X_1603952943517_3_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/severe/7366_A2LEBJJDE00143A_1604393654942_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/severe/4810_A2LEBJJDE00177Y_1606091693650_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/severe/5750_A2LEBJJDE000589_1604213419333_6_BH.jpg
# run: /content/drive/MyDrive/data/dandruff/severe/8146_A2LEBJJDE00148A_1604107363967_2_TH.jpg
# run: /content/drive/MyDrive/data/dandruff/severe/2404_A2LEBJJDE000175_1604135850957_5_RH.jpg
# 2136개의 이미지를 저장했습니다. 파일명: dandruffLoss.npz

# %% [markdown]
# 이미지 확인

# %%
import matplotlib.pyplot as plt

# 이미지 확인
# np.load를 통해 배열 데이터를 가져오고 이를 photos변수에 집어넣는다
# photos 배열 데이터의 x= 이미지 y= 라벨을 각각 집어넣는다.
photos = np.load("dandruffLoss.npz")
x = photos["x"]
y = photos["y"]

# 시작 인덱스 설정
idx = 0  

# subplot으로 인덱스로 설정한 이미지 출력
# plt.figure을 통해 최초 창의 크기를 가로 세로 9인치로 설정한다.
# 20번 반복해서 4행 5열 i+1번째에 이미지를 imshow를 통해 가져와서 출력한다.
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(x[i+idx])
    
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 데이터셋 구분 및 실행

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# npz 파일을 불러와 데이터셋 구분
def preprocessing(file, hairClass):
    global shape, x_train, y_train, x_val, y_val, x_test, y_test
    rows = 256                 # 이미지 높이
    cols = 256                 # 이미지 너비
    color = 3                  # 이미지 색공간
    shape = (rows, cols, color)
    hairClass = hairClass      # 출력 데이터 수
    
    # 사진 데이터 읽기
    # 데이터를 읽은 후 해당 파일의 x(이미지)는 x에  y(라벨 0,1,2,3)은 y에 넣는다.
    photo = np.load(file)
    x = photo['x']
    y = photo['y']
    
    # 데이터 1차원에서 3차원 배열로 변환 및 정규화
    x = x.reshape(-1, rows, cols, color)
    x = x.astype('float32') / 255
    
    # 레이블 One-Hot Encoding 변환
    y = to_categorical(y.astype('int32'), hairClass)
    
    # 전체 데이터셋 -> 학습 데이터셋과 테스트 데이터셋으로 구분
    x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                        test_size=0.2)
    
    # 훈련 데이터셋 -> 학습 데이터셋과 검증 데이터셋으로 구분
    # 만약 train_test_split의 test_size속성이 생략되어 있다면 해당 default값은 0.25이다.
    # 만약 train_test_split의 shuffle속성이 생략되어 있다면 해당 default값은 True이다.
    # 즉 데이터셋를 알아서 섞게 된다.
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
                                                      test_size=0.2)
    
    # 데이터셋 확인
    print(x_train.shape, y_train.shape)
    print(x_val.shape, y_val.shape)
    print(x_test.shape, y_test.shape)

# 데이터셋 구분 실행
# preprocessing을 통해 
preprocessing('dandruffLoss.npz', 4)
# Out:
# (1366, 256, 256, 3) (1366, 4)
# (342, 256, 256, 3) (342, 4)
# (428, 256, 256, 3) (428, 4)

# %% [markdown]
# # ImageNet: 모델 정의

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3, Xception, EfficientNetB2

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import RMSprop, Adam

# trainable 속성을 False로 설정하면 Imagenet 모델의 사전 학습된 가중치를 사용하여 모델의 예측을 생성한다.
# trainable 속성을 True로 설정하면 fine tuning을 수행할 수 있다.

# include_top 속성을 False로 설정하면 기존 Imagenet 모델의 Fully Connected Layer를 제외하고 가져온다.
# include_top 속성을 True로 설정하면 Fully Connected Layer를 포함한 Imagenet 모델을 전부 가져온다.

# VGG16 모델
def def_VGG16(shape, hairClass):
  pre_trained_vgg = VGG16(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_vgg.trainable = False
  model = Sequential()
  model.add(pre_trained_vgg)

  # 레이어 추가(재정의)
  model.add(Flatten())
  model.add(Dense(4096, activation='relu'))
  model.add(Dense(4096, activation='relu'))
  model.add(Dense(hairClass, activation='softmax'))
  
  # 모델 요약
  model.summary()

  # 모델 컴파일 
  model.compile(loss='categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])
  
  return model

# ResNet50 모델
def def_ResNet(shape, hairClass):
  pre_trained_resnet = ResNet50(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_resnet.trainable = False
  model = Sequential()
  model.add(pre_trained_resnet)

  # 레이어 추가(재정의)
  model.add(Flatten())
  model.add(Dense(hairClass, activation='softmax'))

  # 모델 요약
  model.summary() 

  # 모델 컴파일
  model.compile(loss='categorical_crossentropy',
                     optimizer=Adam(),
                     metrics=['accuracy'])  
  
  return model

# InceptionV3 모델
def def_InceptionV3(shape, hairClass):
  pre_trained_inceptionv3 = InceptionV3(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_inceptionv3.trainable = False
  model = Sequential()
  model.add(pre_trained_inceptionv3)

  # 레이어 추가(재정의)
  model.add(GlobalAveragePooling2D())
  model.add(Dense(hairClass, activation='softmax'))
  
  # 모델 요약
  model.summary() 

  # 모델 컴파일
  model.compile(loss='categorical_crossentropy',
                     optimizer=Adam(),
                     metrics=['accuracy'])
  
  return model

# Xception 모델
def def_Xception(shape, hairClass):
  pre_trained_Xception = Xception(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_Xception.trainable = False
  model = Sequential()
  model.add(pre_trained_Xception)

  # 레이어 추가(재정의)
  model.add(GlobalAveragePooling2D())
  model.add(Dense(hairClass, activation='softmax'))

  # 모델 요약 
  model.summary() 

  # 모델 컴파일
  model.compile(loss='categorical_crossentropy',
                     optimizer=Adam(),
                     metrics=['accuracy'])
  
  return model

# EfficientNetB2 모델
def def_EfficientNetB2(shape, hairClass):
  pre_trained_EfficientNetB2 = EfficientNetB2(weights='imagenet', include_top=False, input_shape=shape)
  pre_trained_EfficientNetB2.trainable = False
  model = Sequential()
  model.add(pre_trained_EfficientNetB2)

  # 레이어 추가(재정의)
  model.add(GlobalAveragePooling2D())
  model.add(Dropout(0.3))
  model.add(Dense(hairClass, activation='softmax'))

  # 모델 요약 
  model.summary() 

  # 모델 컴파일
  model.compile(loss='categorical_crossentropy',
                     optimizer=Adam(),
                     metrics=['accuracy'])
  
  return model

# %% [markdown]
# 모델 학습

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

def model_train(x_train, y_train, x_val, y_val, modelFunc, modelName):
  # 모델 생성
  # shape는 데이터셋 구분시 초기화된 변수이다. -> (256, 256, 3)
  model = modelFunc(shape, 4)

  # 모델이 저장될 경로 체크
  model_dir = './model'

  if not os.path.exists(model_dir): # 해당 위치에 경로(폴더)가 없으면
    os.mkdir(model_dir) # 변수명 model_dir로 생성시킴

  # 폴더 경로 변경
  os.chdir('/content/model')

  # 콜백 함수 설정
  # ModelCheckpoint란 모델을 저장할 때 사용하는 콜백 함수이다.
  # filepath -> 모델 저장 경로
  # monitor -> 모델 저장 시 기준이 되는 값으로 해당 코드에서는 val_loss을 저장하게 된다
  # verbose -> 1=저장되었다는 코맨트 0=코맨트 없음
  # save_besr_only -> monitor되는 값을 기준으로 가장 좋은 값을 저장한다.
  checkpoint = ModelCheckpoint(f'dandruff_{modelName}.h5', monitor='val_loss', verbose=1, save_best_only=True)

  # EarlyStopping이란 특정 시점에서 훈련을 멈추는 콜백 함수이다.
  # monitor -> 모니터링할 값
  # mode -> 관찰항목에 대해 개선이 없다고 판단하기 위한 기준을 설정한다. 
  # monitor에서 설정한 항목이 val_loss 이면 값이 감소되지 않을 때 종료하여야 하므로 min을 설정한다. 입력하지 않으면 auto로 설정해 알아서 판단해준다.
  # patience -> 20번 이상 변동 없으면 중지시킨다. -> 일단 다 출력해본다.
  early_stopping = EarlyStopping(monitor='val_loss', patience=20)

  # 모델 훈련
  history = model.fit(x_train, y_train,
                  batch_size=32,
                  epochs=20,
                  verbose=1,
                  validation_data=(x_val, y_val),
                  callbacks=[early_stopping, checkpoint])
  
  # 모델 저장
  model.save(f'dandruff_{modelName}.h5')

  return model, history

# %%
model_VGG16, history_VGG16 = model_train(x_train, y_train, x_val, y_val, def_VGG16, 'VGG16')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 4096)              134221824
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 165,734,212
# Trainable params: 151,019,524
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 5.6471 - accuracy: 0.4143
# Epoch 00001: val_loss improved from inf to 0.87324, saving model to dandruff_VGG16.h5
# 43/43 [==============================] - 41s 639ms/step - loss: 5.6471 - accuracy: 0.4143 - val_loss: 0.8732 - val_accuracy: 0.5877
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8519 - accuracy: 0.6171
# Epoch 00002: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 224ms/step - loss: 0.8519 - accuracy: 0.6171 - val_loss: 0.9859 - val_accuracy: 0.5409
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.7972
# Epoch 00003: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 241ms/step - loss: 0.5043 - accuracy: 0.7972 - val_loss: 1.0849 - val_accuracy: 0.5848
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.8675
# Epoch 00004: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 243ms/step - loss: 0.3493 - accuracy: 0.8675 - val_loss: 1.2204 - val_accuracy: 0.5848
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9107
# Epoch 00005: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 227ms/step - loss: 0.2173 - accuracy: 0.9107 - val_loss: 1.6107 - val_accuracy: 0.5789
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 0.1267 - accuracy: 0.9495
# Epoch 00006: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 248ms/step - loss: 0.1267 - accuracy: 0.9495 - val_loss: 1.7589 - val_accuracy: 0.5789
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9912
# Epoch 00007: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 233ms/step - loss: 0.0339 - accuracy: 0.9912 - val_loss: 2.2070 - val_accuracy: 0.5819
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9846
# Epoch 00008: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 251ms/step - loss: 0.0477 - accuracy: 0.9846 - val_loss: 1.9589 - val_accuracy: 0.5526
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9561
# Epoch 00009: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 256ms/step - loss: 0.1458 - accuracy: 0.9561 - val_loss: 1.8590 - val_accuracy: 0.5819
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9905
# Epoch 00010: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 242ms/step - loss: 0.0253 - accuracy: 0.9905 - val_loss: 2.1581 - val_accuracy: 0.5731
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9802
# Epoch 00011: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 240ms/step - loss: 0.0553 - accuracy: 0.9802 - val_loss: 2.6668 - val_accuracy: 0.5117
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9795
# Epoch 00012: val_loss did not improve from 0.87324
# 43/43 [==============================] - 10s 242ms/step - loss: 0.0565 - accuracy: 0.9795 - val_loss: 2.4704 - val_accuracy: 0.5526
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9890
# Epoch 00013: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 247ms/step - loss: 0.0372 - accuracy: 0.9890 - val_loss: 2.2630 - val_accuracy: 0.5556
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00014: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 263ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.3665 - val_accuracy: 0.5789
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 6.8217e-04 - accuracy: 1.0000
# Epoch 00015: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 266ms/step - loss: 6.8217e-04 - accuracy: 1.0000 - val_loss: 2.4384 - val_accuracy: 0.5702
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 3.6944e-04 - accuracy: 1.0000
# Epoch 00016: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 267ms/step - loss: 3.6944e-04 - accuracy: 1.0000 - val_loss: 2.4642 - val_accuracy: 0.5731
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 2.7291e-04 - accuracy: 1.0000
# Epoch 00017: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 258ms/step - loss: 2.7291e-04 - accuracy: 1.0000 - val_loss: 2.5090 - val_accuracy: 0.5760
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 2.1253e-04 - accuracy: 1.0000
# Epoch 00018: val_loss did not improve from 0.87324
# 43/43 [==============================] - 12s 273ms/step - loss: 2.1253e-04 - accuracy: 1.0000 - val_loss: 2.5617 - val_accuracy: 0.5760
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 1.7348e-04 - accuracy: 1.0000
# Epoch 00019: val_loss did not improve from 0.87324
# 43/43 [==============================] - 11s 258ms/step - loss: 1.7348e-04 - accuracy: 1.0000 - val_loss: 2.6092 - val_accuracy: 0.5731
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 1.4479e-04 - accuracy: 1.0000
# Epoch 00020: val_loss did not improve from 0.87324
# 43/43 [==============================] - 12s 269ms/step - loss: 1.4479e-04 - accuracy: 1.0000 - val_loss: 2.6514 - val_accuracy: 0.5731

# %%
model_ResNet, history_ResNet = model_train(x_train, y_train, x_val, y_val, def_ResNet, 'ResNet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 131072)            0
#
#  dense_3 (Dense)             (None, 4)                 524292
#
# =================================================================
# Total params: 24,112,004
# Trainable params: 524,292
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 7.4047 - accuracy: 0.2687
# Epoch 00001: val_loss improved from inf to 4.14401, saving model to dandruff_ResNet.h5
# 43/43 [==============================] - 15s 221ms/step - loss: 7.4047 - accuracy: 0.2687 - val_loss: 4.1440 - val_accuracy: 0.3070
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 2.0629 - accuracy: 0.3609
# Epoch 00002: val_loss improved from 4.14401 to 2.43812, saving model to dandruff_ResNet.h5
# 43/43 [==============================] - 8s 195ms/step - loss: 2.0629 - accuracy: 0.3609 - val_loss: 2.4381 - val_accuracy: 0.2719
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 2.0491 - accuracy: 0.3690
# Epoch 00003: val_loss improved from 2.43812 to 1.89415, saving model to dandruff_ResNet.h5
# 43/43 [==============================] - 8s 192ms/step - loss: 2.0491 - accuracy: 0.3690 - val_loss: 1.8942 - val_accuracy: 0.3129
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 1.8614 - accuracy: 0.3997
# Epoch 00004: val_loss did not improve from 1.89415
# 43/43 [==============================] - 7s 154ms/step - loss: 1.8614 - accuracy: 0.3997 - val_loss: 2.3907 - val_accuracy: 0.3275
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 1.9236 - accuracy: 0.3887
# Epoch 00005: val_loss improved from 1.89415 to 1.52139, saving model to dandruff_ResNet.h5
# 43/43 [==============================] - 8s 196ms/step - loss: 1.9236 - accuracy: 0.3887 - val_loss: 1.5214 - val_accuracy: 0.4561
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 1.5068 - accuracy: 0.4641
# Epoch 00006: val_loss did not improve from 1.52139
# 43/43 [==============================] - 7s 155ms/step - loss: 1.5068 - accuracy: 0.4641 - val_loss: 2.3993 - val_accuracy: 0.3509
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 1.7355 - accuracy: 0.4458
# Epoch 00007: val_loss improved from 1.52139 to 1.32788, saving model to dandruff_ResNet.h5
# 43/43 [==============================] - 9s 202ms/step - loss: 1.7355 - accuracy: 0.4458 - val_loss: 1.3279 - val_accuracy: 0.4006
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 1.3696 - accuracy: 0.5073
# Epoch 00008: val_loss did not improve from 1.32788
# 43/43 [==============================] - 8s 186ms/step - loss: 1.3696 - accuracy: 0.5073 - val_loss: 1.6375 - val_accuracy: 0.4152
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 1.7168 - accuracy: 0.4561
# Epoch 00009: val_loss did not improve from 1.32788
# 43/43 [==============================] - 7s 162ms/step - loss: 1.7168 - accuracy: 0.4561 - val_loss: 2.8613 - val_accuracy: 0.3538
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2594 - accuracy: 0.5381
# Epoch 00010: val_loss did not improve from 1.32788
# 43/43 [==============================] - 8s 187ms/step - loss: 1.2594 - accuracy: 0.5381 - val_loss: 1.4487 - val_accuracy: 0.4649
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 1.1100 - accuracy: 0.5805
# Epoch 00011: val_loss did not improve from 1.32788
# 43/43 [==============================] - 8s 189ms/step - loss: 1.1100 - accuracy: 0.5805 - val_loss: 3.3881 - val_accuracy: 0.3889
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2741 - accuracy: 0.5644
# Epoch 00012: val_loss did not improve from 1.32788
# 43/43 [==============================] - 7s 155ms/step - loss: 1.2741 - accuracy: 0.5644 - val_loss: 1.4409 - val_accuracy: 0.4649
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2086 - accuracy: 0.5659
# Epoch 00013: val_loss did not improve from 1.32788
# 43/43 [==============================] - 8s 189ms/step - loss: 1.2086 - accuracy: 0.5659 - val_loss: 1.5652 - val_accuracy: 0.4094
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2127 - accuracy: 0.5490
# Epoch 00014: val_loss did not improve from 1.32788
# 43/43 [==============================] - 7s 155ms/step - loss: 1.2127 - accuracy: 0.5490 - val_loss: 2.0504 - val_accuracy: 0.3509
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 2.3452 - accuracy: 0.4502
# Epoch 00015: val_loss did not improve from 1.32788
# 43/43 [==============================] - 8s 188ms/step - loss: 2.3452 - accuracy: 0.4502 - val_loss: 2.4218 - val_accuracy: 0.3947
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2163 - accuracy: 0.5864
# Epoch 00016: val_loss did not improve from 1.32788
# 43/43 [==============================] - 8s 185ms/step - loss: 1.2163 - accuracy: 0.5864 - val_loss: 1.3727 - val_accuracy: 0.4912
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 0.9231 - accuracy: 0.6193
# Epoch 00017: val_loss improved from 1.32788 to 1.31127, saving model to dandruff_ResNet.h5
# 43/43 [==============================] - 7s 165ms/step - loss: 0.9231 - accuracy: 0.6193 - val_loss: 1.3113 - val_accuracy: 0.4474
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8822 - accuracy: 0.6406
# Epoch 00018: val_loss did not improve from 1.31127
# 43/43 [==============================] - 7s 158ms/step - loss: 0.8822 - accuracy: 0.6406 - val_loss: 1.7319 - val_accuracy: 0.3713
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8904 - accuracy: 0.6471
# Epoch 00019: val_loss did not improve from 1.31127
# 43/43 [==============================] - 7s 155ms/step - loss: 0.8904 - accuracy: 0.6471 - val_loss: 1.9431 - val_accuracy: 0.3743
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 1.3568 - accuracy: 0.5527
# Epoch 00020: val_loss did not improve from 1.31127
# 43/43 [==============================] - 8s 188ms/step - loss: 1.3568 - accuracy: 0.5527 - val_loss: 1.8404 - val_accuracy: 0.4708

# %%
model_Inception, history_Inception = model_train(x_train, y_train, x_val, y_val, def_InceptionV3, 'Inception')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 4)                 8196
#
# =================================================================
# Total params: 21,810,980
# Trainable params: 8,196
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2583 - accuracy: 0.4114
# Epoch 00001: val_loss improved from inf to 1.12815, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 16s 209ms/step - loss: 1.2583 - accuracy: 0.4114 - val_loss: 1.1282 - val_accuracy: 0.4561
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 1.0304 - accuracy: 0.5439
# Epoch 00002: val_loss improved from 1.12815 to 1.05641, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 141ms/step - loss: 1.0304 - accuracy: 0.5439 - val_loss: 1.0564 - val_accuracy: 0.5058
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 0.9533 - accuracy: 0.5761
# Epoch 00003: val_loss improved from 1.05641 to 1.04332, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 134ms/step - loss: 0.9533 - accuracy: 0.5761 - val_loss: 1.0433 - val_accuracy: 0.5292
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8899 - accuracy: 0.6076
# Epoch 00004: val_loss improved from 1.04332 to 1.02263, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 139ms/step - loss: 0.8899 - accuracy: 0.6076 - val_loss: 1.0226 - val_accuracy: 0.5029
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8434 - accuracy: 0.6369
# Epoch 00005: val_loss improved from 1.02263 to 1.01459, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 131ms/step - loss: 0.8434 - accuracy: 0.6369 - val_loss: 1.0146 - val_accuracy: 0.5058
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.6567
# Epoch 00006: val_loss improved from 1.01459 to 0.98040, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 136ms/step - loss: 0.8114 - accuracy: 0.6567 - val_loss: 0.9804 - val_accuracy: 0.5263
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7668 - accuracy: 0.6859
# Epoch 00007: val_loss did not improve from 0.98040
# 43/43 [==============================] - 6s 129ms/step - loss: 0.7668 - accuracy: 0.6859 - val_loss: 0.9851 - val_accuracy: 0.5585
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7378 - accuracy: 0.6999
# Epoch 00008: val_loss improved from 0.98040 to 0.97924, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 130ms/step - loss: 0.7378 - accuracy: 0.6999 - val_loss: 0.9792 - val_accuracy: 0.5673
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7150 - accuracy: 0.7247
# Epoch 00009: val_loss improved from 0.97924 to 0.94784, saving model to dandruff_Inception.h5
# 43/43 [==============================] - 6s 139ms/step - loss: 0.7150 - accuracy: 0.7247 - val_loss: 0.9478 - val_accuracy: 0.5526
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.7416
# Epoch 00010: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 127ms/step - loss: 0.6890 - accuracy: 0.7416 - val_loss: 0.9983 - val_accuracy: 0.5556
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.7387
# Epoch 00011: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 127ms/step - loss: 0.6866 - accuracy: 0.7387 - val_loss: 0.9813 - val_accuracy: 0.5614
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6841 - accuracy: 0.7394
# Epoch 00012: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 126ms/step - loss: 0.6841 - accuracy: 0.7394 - val_loss: 0.9623 - val_accuracy: 0.5731
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6380 - accuracy: 0.7584
# Epoch 00013: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 121ms/step - loss: 0.6380 - accuracy: 0.7584 - val_loss: 0.9744 - val_accuracy: 0.5556
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6278 - accuracy: 0.7657
# Epoch 00014: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 128ms/step - loss: 0.6278 - accuracy: 0.7657 - val_loss: 0.9621 - val_accuracy: 0.5643
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.7862
# Epoch 00015: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 128ms/step - loss: 0.6032 - accuracy: 0.7862 - val_loss: 0.9514 - val_accuracy: 0.5643
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5854 - accuracy: 0.8031
# Epoch 00016: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 127ms/step - loss: 0.5854 - accuracy: 0.8031 - val_loss: 1.0010 - val_accuracy: 0.5585
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5860 - accuracy: 0.7899
# Epoch 00017: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 124ms/step - loss: 0.5860 - accuracy: 0.7899 - val_loss: 0.9662 - val_accuracy: 0.5556
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.8031
# Epoch 00018: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 118ms/step - loss: 0.5688 - accuracy: 0.8031 - val_loss: 0.9572 - val_accuracy: 0.5789
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5564 - accuracy: 0.8016
# Epoch 00019: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 126ms/step - loss: 0.5564 - accuracy: 0.8016 - val_loss: 0.9636 - val_accuracy: 0.5673
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 0.8119
# Epoch 00020: val_loss did not improve from 0.94784
# 43/43 [==============================] - 5s 128ms/step - loss: 0.5559 - accuracy: 0.8119 - val_loss: 0.9689 - val_accuracy: 0.5468

# %%
model_Xception, history_Xception = model_train(x_train, y_train, x_val, y_val, def_Xception, 'Xception')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 8, 8, 2048)        20861480
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 4)                 8196
#
# =================================================================
# Total params: 20,869,676
# Trainable params: 8,196
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 1.2143 - accuracy: 0.4341
# Epoch 00001: val_loss improved from inf to 1.01411, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 17s 286ms/step - loss: 1.2143 - accuracy: 0.4341 - val_loss: 1.0141 - val_accuracy: 0.5673
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 0.9859 - accuracy: 0.5732
# Epoch 00002: val_loss improved from 1.01411 to 0.95614, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 240ms/step - loss: 0.9859 - accuracy: 0.5732 - val_loss: 0.9561 - val_accuracy: 0.5848
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 0.9155 - accuracy: 0.5952
# Epoch 00003: val_loss improved from 0.95614 to 0.90876, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 225ms/step - loss: 0.9155 - accuracy: 0.5952 - val_loss: 0.9088 - val_accuracy: 0.6023
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8492 - accuracy: 0.6413
# Epoch 00004: val_loss improved from 0.90876 to 0.90038, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 238ms/step - loss: 0.8492 - accuracy: 0.6413 - val_loss: 0.9004 - val_accuracy: 0.6257
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8046 - accuracy: 0.6757
# Epoch 00005: val_loss improved from 0.90038 to 0.88518, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 227ms/step - loss: 0.8046 - accuracy: 0.6757 - val_loss: 0.8852 - val_accuracy: 0.5936
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7794 - accuracy: 0.6925
# Epoch 00006: val_loss improved from 0.88518 to 0.87787, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 11s 246ms/step - loss: 0.7794 - accuracy: 0.6925 - val_loss: 0.8779 - val_accuracy: 0.6287
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7584 - accuracy: 0.6947
# Epoch 00007: val_loss improved from 0.87787 to 0.85248, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 245ms/step - loss: 0.7584 - accuracy: 0.6947 - val_loss: 0.8525 - val_accuracy: 0.6111
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7359 - accuracy: 0.7130
# Epoch 00008: val_loss did not improve from 0.85248
# 43/43 [==============================] - 10s 236ms/step - loss: 0.7359 - accuracy: 0.7130 - val_loss: 0.8591 - val_accuracy: 0.6345
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7091 - accuracy: 0.7306
# Epoch 00009: val_loss improved from 0.85248 to 0.84046, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 11s 247ms/step - loss: 0.7091 - accuracy: 0.7306 - val_loss: 0.8405 - val_accuracy: 0.6140
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.7042
# Epoch 00010: val_loss did not improve from 0.84046
# 43/43 [==============================] - 10s 223ms/step - loss: 0.7039 - accuracy: 0.7042 - val_loss: 0.8420 - val_accuracy: 0.6462
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.7430
# Epoch 00011: val_loss did not improve from 0.84046
# 43/43 [==============================] - 10s 222ms/step - loss: 0.6775 - accuracy: 0.7430 - val_loss: 0.8576 - val_accuracy: 0.6287
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.7445
# Epoch 00012: val_loss improved from 0.84046 to 0.83774, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6625 - accuracy: 0.7445 - val_loss: 0.8377 - val_accuracy: 0.6170
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.7533
# Epoch 00013: val_loss did not improve from 0.83774
# 43/43 [==============================] - 9s 221ms/step - loss: 0.6513 - accuracy: 0.7533 - val_loss: 0.8462 - val_accuracy: 0.6404
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.7621
# Epoch 00014: val_loss did not improve from 0.83774
# 43/43 [==============================] - 10s 239ms/step - loss: 0.6270 - accuracy: 0.7621 - val_loss: 0.8529 - val_accuracy: 0.6199
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.7606
# Epoch 00015: val_loss did not improve from 0.83774
# 43/43 [==============================] - 9s 219ms/step - loss: 0.6235 - accuracy: 0.7606 - val_loss: 0.8650 - val_accuracy: 0.6170
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6005 - accuracy: 0.7796
# Epoch 00016: val_loss improved from 0.83774 to 0.83156, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 228ms/step - loss: 0.6005 - accuracy: 0.7796 - val_loss: 0.8316 - val_accuracy: 0.6287
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5960 - accuracy: 0.7804
# Epoch 00017: val_loss improved from 0.83156 to 0.82712, saving model to dandruff_Xception.h5
# 43/43 [==============================] - 10s 246ms/step - loss: 0.5960 - accuracy: 0.7804 - val_loss: 0.8271 - val_accuracy: 0.6462
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5769 - accuracy: 0.8045
# Epoch 00018: val_loss did not improve from 0.82712
# 43/43 [==============================] - 10s 222ms/step - loss: 0.5769 - accuracy: 0.8045 - val_loss: 0.8454 - val_accuracy: 0.6228
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.7994
# Epoch 00019: val_loss did not improve from 0.82712
# 43/43 [==============================] - 9s 220ms/step - loss: 0.5692 - accuracy: 0.7994 - val_loss: 0.8769 - val_accuracy: 0.6345
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5612 - accuracy: 0.8045
# Epoch 00020: val_loss did not improve from 0.82712
# 43/43 [==============================] - 10s 239ms/step - loss: 0.5612 - accuracy: 0.8045 - val_loss: 0.8485 - val_accuracy: 0.6404

# %% [markdown]
# EfficientNet 파일 저장 오류
# [오류 해결 링크](https://discuss.tensorflow.org/t/using-efficientnetb0-and-save-model-will-result-unable-to-serialize-2-0896919-2-1128857-2-1081853-to-json-unrecognized-type-class-tensorflow-python-framework-ops-eagertensor/12518/12)

# %%
model_EfficientNet, history_EfficientNet = model_train(x_train, y_train, x_val, y_val, def_EfficientNetB2, 'EfficientNet')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 [==============================] - 1s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 8, 8, 1408)       7768569
#
#  global_average_pooling2d_2   (None, 1408)             0
#  (GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1408)              0
#
#  dense_6 (Dense)             (None, 4)                 5636
#
# =================================================================
# Total params: 7,774,205
# Trainable params: 5,636
# Non-trainable params: 7,768,569
# _________________________________________________________________
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 1.4151 - accuracy: 0.2387
# Epoch 00001: val_loss improved from inf to 1.38963, saving model to dandruff_EfficientNet.h5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a928a857cf13> in <cell line: 1>()
# ----> 1 model_EfficientNet, history_EfficientNet = model_train(x_train, y_train, x_val, y_val, def_EfficientNetB2, 'EfficientNet')
#
# <ipython-input-7-f4a4205b58bd> in model_train(x_train, y_train, x_val, y_val, modelFunc, modelName)
#      31
#      32   # 모델 훈련
# ---> 33   history = model.fit(x_train, y_train,
#      34                   batch_size=32,
#      35                   epochs=20,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/lib/python3.10/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.10/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.10/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# TypeError: Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.

# %% [markdown]
# history 확인

# %%
print(history_VGG16.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

def model_plot(history, modelName):
  # loss
  y_loss = history.history['loss']
  y_vloss = history.history['val_loss']
  
  x_len = range(1,len(y_loss) + 1)

  fig = plt.figure(figsize=(10, 4))
  ax = fig.add_subplot(1, 2, 1)

  ax.plot(x_len, y_loss, marker='.', c='blue', label='train_set_loss')
  ax.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
  ax.set_xlabel('Epochs')
  ax.set_ylabel('Loss')
  ax.set_title(modelName + ': train&val loss')
  ax.legend()

  # accuracy
  y_acc = history.history['accuracy']
  y_vacc = history.history['val_accuracy']
  
  x_len = range(1, len(y_acc) + 1)
  ax = fig.add_subplot(1, 2, 2)
  ax.plot(x_len, y_acc, marker='.', c='blue', label='train_set_acc')
  ax.plot(x_len, y_vacc, marker='.', c='red', label='val_set_acc')
  ax.set_xlabel('Epochs')
  ax.set_ylabel('Accuracy')
  ax.set_title(modelName + ': train&val accuracy')
  ax.legend()

  plt.tight_layout()
  plt.show()

# %%
model_history = [ history_VGG16, history_ResNet, history_Inception, history_Xception ]
model_Name = ['VGG16', 'ResNet', 'Inception', 'Xception']

for i in range(4):
  model_plot(model_history[i], model_Name[i])

# model_plot(history_VGG16, 'VGG16')
# model_plot(history_ResNet, 'ResNet')
# model_plot(history_Inception, 'Inception')
# model_plot(history_Xception, 'Xception')

# %% [markdown]
# ## Confusion Matrix

# %%
from keras.models import load_model
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# history와 model을 이용한 방법
def confusionMatrix_model(model, modelName, x_test, y_test):
    # 모델을 이용해 테스트 데이터셋에 대한 예측 수행
    y_pred = model.predict(x_test)

    # softmax 확률 출력을 가장 높은 확률을 가진 클래스로 변환
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Labeling
    label = ['normal', 'mild', 'moderate', 'severe']
    
    # 혼동 행렬 생성
    cm = confusion_matrix(y_true, y_pred_classes)

    # 혼동 행렬 시각화
    plt.figure(figsize=(7,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label, yticklabels=label)
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.title(modelName + ' confusionMatrix')
    plt.show()

    # 분류 보고서 출력
    print(classification_report(y_true, y_pred_classes))

    
# 생성된 .h5 파일을 이용하여 생성
def confusionMatrix_h5(model_path, modelName, x_test, y_test):
    
    # 모델 로드
    model = load_model(model_path)

    # 테스트 데이터셋에 대한 예측 수행
    y_pred = model.predict(x_test)

    # 예측 결과를 가장 높은 확률을 가진 클래스로 변환
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # 혼동 행렬 생성
    cm = confusion_matrix(y_true, y_pred_classes)

    # 혼동 행렬 시각화
    plt.figure(figsize=(7,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.title(modelName + ' confusionMatrix')
    plt.show()

# %%
model_train_result = [ model_VGG16, model_ResNet, model_Inception, model_Xception ]
model_Name = ['VGG16', 'ResNet', 'Inception', 'Xception']
for i in range(4):
  confusionMatrix_model(model_train_result[i], model_Name[i], x_test, y_test)

# confusionMatrix_model(model_VGG16, x_test, y_test)
# confusionMatrix_model(model_Resnet, x_test, y_test)
# confusionMatrix_model(model_Inception, x_test, y_test)
# confusionMatrix_model(model_Xception, x_test, y_test)
# Out:
# 14/14 [==============================] - 5s 330ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       130
#            1       0.50      0.57      0.53       104
#            2       0.44      0.48      0.46       100
#            3       0.71      0.66      0.69        94
#
#     accuracy                           0.62       428
#    macro avg       0.63      0.62      0.62       428
# weighted avg       0.64      0.62      0.63       428
#
# 14/14 [==============================] - 3s 172ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64       130
#            1       0.00      0.00      0.00       104
#            2       0.43      0.23      0.30       100
#            3       0.43      0.84      0.57        94
#
#     accuracy                           0.48       428
#    macro avg       0.35      0.47      0.38       428
# weighted avg       0.36      0.48      0.39       428
#
# 14/14 [==============================] - 4s 178ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75       130
#            1       0.40      0.37      0.38       104
#            2       0.36      0.52      0.43       100
#            3       0.70      0.65      0.67        94
#
#     accuracy                           0.56       428
#    macro avg       0.58      0.55      0.56       428
# weighted avg       0.59      0.56      0.57       428
#
# 14/14 [==============================] - 4s 221ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79       130
#            1       0.50      0.48      0.49       104
#            2       0.39      0.32      0.35       100
#            3       0.59      0.79      0.68        94
#
#     accuracy                           0.60       428
#    macro avg       0.58      0.59      0.58       428
# weighted avg       0.59      0.60      0.59       428

# %% [markdown]
# model 테스트

# %%
def model_evaluate(model, x_test, y_test):
    test_result = model.evaluate(x_test, y_test, verbose=1)
    print("acc: ", test_result[1], 'loss: ', test_result[0])

    return test_result[1], test_result[0]

# %%
accuracy_VGG16 = None
accuracy_ResNet = None
accuracy_Inception = None
accuracy_Xception = None
loss_VGG16 = None
loss_ResNet = None
loss_Inception = None
loss_Xception = None

accuracy = [ accuracy_VGG16, accuracy_ResNet, accuracy_Inception, accuracy_Xception ]
loss = [ loss_VGG16, loss_ResNet, loss_Inception, loss_Xception ]
model_train_result = [ model_VGG16, model_ResNet, model_Inception, model_Xception ]

for i in range(4):
  accuracy[i], loss[i] = model_evaluate(model_train_result[i], x_test, y_test)
  print("\n")

# accuracy_VGG16, loss_VGG16 = evaluate_model(model_VGG16, x_test, y_test)
# accuracy_Resnet, loss_Resnet = evaluate_model(model_ResNet, x_test, y_test)
# accuracy_Inception, loss_Inception = evaluate_model(model_Inception, x_test, y_test)
# accuracy_Xception, loss_Xception = evaluate_model(model_Xception, x_test, y_test)
# Out:
# 14/14 [==============================] - 2s 157ms/step - loss: 2.4830 - accuracy: 0.6238
# acc:  0.6238317489624023 loss:  2.4830069541931152
#
#
# 14/14 [==============================] - 2s 111ms/step - loss: 1.7406 - accuracy: 0.4790
# acc:  0.4789719581604004 loss:  1.7405844926834106
#
#
# 14/14 [==============================] - 1s 91ms/step - loss: 0.9849 - accuracy: 0.5584
# acc:  0.5584112405776978 loss:  0.9848929643630981
#
#
# 14/14 [==============================] - 2s 155ms/step - loss: 0.8804 - accuracy: 0.5958
# acc:  0.5957943797111511 loss:  0.880386471748352

# %% [markdown]
# 파일 다운로드

# %%
from google.colab import files
# files.download('/content/model/dandruff_Inception.h5')
# files.download('/content/model/dandruff_ResNet.h5')
# files.download('/content/model/dandruff_VGG16.h5')
# files.download('/content/model/dandruff_Xception.h5')
# files.download('/content/dandruffLoss.npz')
